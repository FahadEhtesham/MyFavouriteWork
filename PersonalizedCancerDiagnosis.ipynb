# %% [markdown]
# <p style="font-size:36px;text-align:center"> <b>Personalized cancer diagnosis</b> </p>

# %% [markdown]
# <h1>1. Business Problem</h1>

# %% [markdown]
# <h2>1.1. Description</h2>

# %% [markdown]
# <p> Classify the given genetic variations/mutations based on evidence from text-based clinical literature. </p>

# %% [markdown]
# <h2>1.3. Real-world/Business objectives and constraints.</h2>

# %% [markdown]
# * No low-latency requirement.
# * Interpretability is important.
# * Errors can be very costly.
# * Probability of a data-point belonging to each class is needed.

# %% [markdown]
# <h1>2. Machine Learning Problem Formulation</h1>

# %% [markdown]
# <h2>2.1. Data</h2>

# %% [markdown]
# <h3>2.1.1. Data Overview</h3>

# %% [markdown]
# - We have two data files: one conatins the information about the genetic mutations and the other contains the clinical evidence (text) that  human experts/pathologists use to classify the genetic mutations.
# - Both these data files are have a common column called ID
# - <p>
#     Data file's information:
#     <ul>
#         <li>
#         training_variants (ID , Gene, Variations, Class)
#         </li>
#         <li>
#         training_text (ID, Text)
#         </li>
#     </ul>
# </p>

# %% [markdown]
# <h3>2.1.2. Example Data Point</h3>

# %% [markdown]
# <h6>training_variants</h6>
# <hr>
# ID,Gene,Variation,Class<br>
# 0,FAM58A,Truncating Mutations,1 <br>
# 1,CBL,W802*,2 <br>
# 2,CBL,Q249E,2 <br>
# ...
#
# <h6> training_text</h6>
# <hr>
# ID,Text <br>
# 0||Cyclin-dependent kinases (CDKs) regulate a variety of fundamental cellular processes. CDK10 stands out as one of the last orphan CDKs for which no activating cyclin has been identified and no kinase activity revealed. Previous work has shown that CDK10 silencing increases ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2)-driven activation of the MAPK pathway, which confers tamoxifen resistance to breast cancer cells. The precise mechanisms by which CDK10 modulates ETS2 activity, and more generally the functions of CDK10, remain elusive. Here we demonstrate that CDK10 is a cyclin-dependent kinase by identifying cyclin M as an activating cyclin. Cyclin M, an orphan cyclin, is the product of FAM58A, whose mutations cause STAR syndrome, a human developmental anomaly whose features include toe syndactyly, telecanthus, and anogenital and renal malformations. We show that STAR syndrome-associated cyclin M mutants are unable to interact with CDK10. Cyclin M silencing phenocopies CDK10 silencing in increasing c-Raf and in conferring tamoxifen resistance to breast cancer cells. CDK10/cyclin M phosphorylates ETS2 in vitro, and in cells it positively controls ETS2 degradation by the proteasome. ETS2 protein levels are increased in cells derived from a STAR patient, and this increase is attributable to decreased cyclin M levels. Altogether, our results reveal an additional regulatory mechanism for ETS2, which plays key roles in cancer and development. They also shed light on the molecular mechanisms underlying STAR syndrome.Cyclin-dependent kinases (CDKs) play a pivotal role in the control of a number of fundamental cellular processes (1). The human genome contains 21 genes encoding proteins that can be considered as members of the CDK family owing to their sequence similarity with bona fide CDKs, those known to be activated by cyclins (2). Although discovered almost 20 y ago (3, 4), CDK10 remains one of the two CDKs without an identified cyclin partner. This knowledge gap has largely impeded the exploration of its biological functions. CDK10 can act as a positive cell cycle regulator in some cells (5, 6) or as a tumor suppressor in others (7, 8). CDK10 interacts with the ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2) transcription factor and inhibits its transcriptional activity through an unknown mechanism (9). CDK10 knockdown derepresses ETS2, which increases the expression of the c-Raf protein kinase, activates the MAPK pathway, and induces resistance of MCF7 cells to tamoxifen (6). ...

# %% [markdown]
# <h2>2.2. Mapping the real-world problem to an ML problem</h2>

# %% [markdown]
# <h3>2.2.1. Type of Machine Learning Problem</h3>

# %% [markdown]
# <p>
#
#             There are nine different classes a genetic mutation can be classified into => Multi class classification problem
#
#
#
# </p>

# %% [markdown]
# <h3>2.2.2. Performance Metric</h3>

# %% [markdown]
# Metric(s):
# * Multi class log-loss
# * Confusion matrix

# %% [markdown]
# <h3>2.2.3. Machine Learing Objectives and Constraints</h3>

# %% [markdown]
# <p> Objective: Predict the probability of each data-point belonging to each of the nine classes.
# </p>
# <p> Constraints:
# </p>
# * Interpretability
# * Class probabilities are needed.
# * Penalize the errors in class probabilites => Metric is Log-loss.
# * No Latency constraints.

# %% [markdown]
# <h2>2.3. Train, CV and Test Datasets</h2>

# %% [markdown]
#  Split the dataset randomly into three parts train, cross validation and test with 64%,16%, 20% of data respectively

# %% [markdown]
# <h1>3. Exploratory Data Analysis</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import numpy as np
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from imblearn.over_sampling import SMOTE
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold 
from collections import Counter, defaultdict
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from sklearn.metrics import normalized_mutual_info_score
from sklearn.ensemble import RandomForestClassifier

warnings.filterwarnings("ignore")

from mlxtend.classifier import StackingClassifier

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# <h2>3.1. Reading Data</h2>

# %% [markdown]
# <h3>3.1.1. Reading Gene and Variation Data</h3>

# %%
#data = pd.read_csv('training/training_variants')
data = pd.read_csv('/content/gdrive/My Drive/training_variants')
print('Number of data points : ', data.shape[0])
print('Number of features : ', data.shape[1])
print('Features : ', data.columns.values)
data.head()
# Out:
# Number of data points :  3321
# Number of features :  4
# Features :  ['ID' 'Gene' 'Variation' 'Class']
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %% [markdown]
# <p>
#     training/training_variants is a comma separated file containing the description of the genetic mutations used for training. <br>
#     Fields are
#     <ul>
#         <li><b>ID : </b>the id of the row used to link the mutation to the clinical evidence</li>
#         <li><b>Gene : </b>the gene where this genetic mutation is located </li>
#         <li><b>Variation : </b>the aminoacid change for this mutations </li>
#         <li><b>Class :</b> 1-9 the class this genetic mutation has been classified on</li>
#     </ul>

# %% [markdown]
# <h3>3.1.2. Reading Text Data</h3>

# %%
# note the seprator in this file
data_text =pd.read_csv('/content/gdrive/My Drive/training_text',sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)
print('Number of data points : ', data_text.shape[0])
print('Number of features : ', data_text.shape[1])
print('Features : ', data_text.columns.values)
data_text.head()
# Out:
# Number of data points :  3321
# Number of features :  2
# Features :  ['ID' 'TEXT']
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %% [markdown]
# <h3>3.1.3. Preprocessing of text</h3>

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# loading stop words from nltk library
stop_words = set(stopwords.words('english'))


def nlp_preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', total_text)
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', total_text)
        # converting all the chars into lower-case.
        total_text = total_text.lower()
        
        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                string += word + " "
                
        data_text[column][index] = string
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#text processing stage.
start_time = time.clock()
for index, row in data_text.iterrows():
    if type(row['TEXT']) is str:
        nlp_preprocessing(row['TEXT'], index, 'TEXT')
    else:
        print("there is no text description for id:",index)
print('Time took for preprocessing the text :',time.clock() - start_time, "seconds")
# Out:
# there is no text description for id: 1109
# there is no text description for id: 1277
# there is no text description for id: 1407
# there is no text description for id: 1639
# there is no text description for id: 2755
# Time took for preprocessing the text : 333.87812599999995 seconds

# %%
#merging both gene_variations and text data based on ID
result = pd.merge(data, data_text,on ='ID', how='left')
result.head()
# Out:
#    ID    Gene  ... Class                                               TEXT
# 0   0  FAM58A  ...     1  cyclin dependent kinases cdks regulate variety...
# 1   1     CBL  ...     2  abstract background non small cell lung cancer...
# 2   2     CBL  ...     2  abstract background non small cell lung cancer...
# 3   3     CBL  ...     3  recent evidence demonstrated acquired uniparen...
# 4   4     CBL  ...     4  oncogenic mutations monomeric casitas b lineag...
#
# [5 rows x 5 columns]

# %%
result[result.isnull().any(axis=1)]
# Out:
#         ID    Gene             Variation  Class TEXT
# 1109  1109   FANCA                S1088F      1  NaN
# 1277  1277  ARID5B  Truncating Mutations      1  NaN
# 1407  1407   FGFR3                 K508M      6  NaN
# 1639  1639    FLT1         Amplification      6  NaN
# 2755  2755    BRAF                 G596C      7  NaN

# %%
result.loc[result['TEXT'].isnull(),'TEXT'] = result['Gene'] +' '+result['Variation']

# %%
result[result['ID']==2755]
# Out:
#         ID  Gene Variation  Class        TEXT
# 2755  2755  BRAF     G596C      7  BRAF G596C

# %% [markdown]
# <h3>3.1.4. Test, Train and Cross Validation Split</h3>

# %% [markdown]
# <h4>3.1.4.1. Splitting data into train, test and cross validation (64:20:16)</h4>

# %%
y_true = result['Class'].values
result.Gene      = result.Gene.str.replace('\s+', '_')
result.Variation = result.Variation.str.replace('\s+', '_')

# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(result, y_true, stratify=y_true, test_size=0.2)
# split the train data into train and cross validation by maintaining same distribution of output varaible 'y_train' [stratify=y_train]
train_df, cv_df, y_train, y_cv = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2)

# %% [markdown]
# <p> We split the data into train, test and cross validation data sets, preserving the ratio of class distribution in the original data set  </p>

# %%
print('Number of data points in train data:', train_df.shape[0])
print('Number of data points in test data:', test_df.shape[0])
print('Number of data points in cross validation data:', cv_df.shape[0])
# Out:
# Number of data points in train data: 2124
# Number of data points in test data: 665
# Number of data points in cross validation data: 532

# %% [markdown]
# <h4>3.1.4.2. Distribution of y_i's in Train, Test and Cross Validation datasets</h4>

# %%
# it returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = train_df['Class'].value_counts().sort_index()
test_class_distribution = test_df['Class'].value_counts().sort_index()
cv_class_distribution = cv_df['Class'].value_counts().sort_index()

my_colors = 'rgbkymc'
train_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in train data')
plt.grid()
plt.show()

# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',train_class_distribution.values[i], '(', np.round((train_class_distribution.values[i]/train_df.shape[0]*100), 3), '%)')

    
print('-'*80)
my_colors = 'rgbkymc'
test_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in test data')
plt.grid()
plt.show()

# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-test_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',test_class_distribution.values[i], '(', np.round((test_class_distribution.values[i]/test_df.shape[0]*100), 3), '%)')

print('-'*80)
my_colors = 'rgbkymc'
cv_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in cross validation data')
plt.grid()
plt.show()

# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',cv_class_distribution.values[i], '(', np.round((cv_class_distribution.values[i]/cv_df.shape[0]*100), 3), '%)')
# Out:
# Number of data points in class 7 : 609 ( 28.672 %)
# Number of data points in class 4 : 439 ( 20.669 %)
# Number of data points in class 1 : 363 ( 17.09 %)
# Number of data points in class 2 : 289 ( 13.606 %)
# Number of data points in class 6 : 176 ( 8.286 %)
# Number of data points in class 5 : 155 ( 7.298 %)
# Number of data points in class 3 : 57 ( 2.684 %)
# Number of data points in class 9 : 24 ( 1.13 %)
# Number of data points in class 8 : 12 ( 0.565 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 191 ( 28.722 %)
# Number of data points in class 4 : 137 ( 20.602 %)
# Number of data points in class 1 : 114 ( 17.143 %)
# Number of data points in class 2 : 91 ( 13.684 %)
# Number of data points in class 6 : 55 ( 8.271 %)
# Number of data points in class 5 : 48 ( 7.218 %)
# Number of data points in class 3 : 18 ( 2.707 %)
# Number of data points in class 9 : 7 ( 1.053 %)
# Number of data points in class 8 : 4 ( 0.602 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 153 ( 28.759 %)
# Number of data points in class 4 : 110 ( 20.677 %)
# Number of data points in class 1 : 91 ( 17.105 %)
# Number of data points in class 2 : 72 ( 13.534 %)
# Number of data points in class 6 : 44 ( 8.271 %)
# Number of data points in class 5 : 39 ( 7.331 %)
# Number of data points in class 3 : 14 ( 2.632 %)
# Number of data points in class 9 : 6 ( 1.128 %)
# Number of data points in class 8 : 3 ( 0.564 %)

# %% [markdown]
# <h2>3.2 Prediction using a 'Random' Model</h2>

# %% [markdown]
# <p style="font-size:16px"> In a 'Random' Model, we generate the NINE class probabilites randomly such that they sum to 1. </p>

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    
    labels = [1,2,3,4,5,6,7,8,9]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
# we need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
test_data_len = test_df.shape[0]
cv_data_len = cv_df.shape[0]

# we create a output array that has exactly same size as the CV data
cv_predicted_y = np.zeros((cv_data_len,9))
for i in range(cv_data_len):
    rand_probs = np.random.rand(1,9)
    cv_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Cross Validation Data using Random Model",log_loss(y_cv,cv_predicted_y, eps=1e-15))


# Test-Set error.
#we create a output array that has exactly same as the test data
test_predicted_y = np.zeros((test_data_len,9))
for i in range(test_data_len):
    rand_probs = np.random.rand(1,9)
    test_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test,test_predicted_y, eps=1e-15))

predicted_y =np.argmax(test_predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y+1)
# Out:
# Log loss on Cross Validation Data using Random Model 2.427764772077063
# Log loss on Test Data using Random Model 2.442983532178961
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h2>3.3 Univariate Analysis</h2>

# %%
# code for response coding with Laplace smoothing.
# alpha : used for laplace smoothing
# feature: ['gene', 'variation']
# df: ['train_df', 'test_df', 'cv_df']
# algorithm
# ----------
# Consider all unique values and the number of occurances of given feature in train data dataframe
# build a vector (1*9) , the first element = (number of times it occured in class1 + 10*alpha / number of time it occurred in total data+90*alpha)
# gv_dict is like a look up table, for every gene it store a (1*9) representation of it
# for a value of feature in df:
# if it is in train data:
# we add the vector that was stored in 'gv_dict' look up table to 'gv_fea'
# if it is not there is train:
# we add [1/9, 1/9, 1/9, 1/9,1/9, 1/9, 1/9, 1/9, 1/9] to 'gv_fea'
# return 'gv_fea'
# ----------------------

# get_gv_fea_dict: Get Gene varaition Feature Dict
def get_gv_fea_dict(alpha, feature, df):
    # value_count: it contains a dict like
    # print(train_df['Gene'].value_counts())
    # output:
    #        {BRCA1      174
    #         TP53       106
    #         EGFR        86
    #         BRCA2       75
    #         PTEN        69
    #         KIT         61
    #         BRAF        60
    #         ERBB2       47
    #         PDGFRA      46
    #         ...}
    # print(train_df['Variation'].value_counts())
    # output:
    # {
    # Truncating_Mutations                     63
    # Deletion                                 43
    # Amplification                            43
    # Fusions                                  22
    # Overexpression                            3
    # E17K                                      3
    # Q61L                                      3
    # S222D                                     2
    # P130S                                     2
    # ...
    # }
    value_count = train_df[feature].value_counts()
    
    # gv_dict : Gene Variation Dict, which contains the probability array for each gene/variation
    gv_dict = dict()
    
    # denominator will contain the number of time that particular feature occured in whole data
    for i, denominator in value_count.items():
        # vec will contain (p(yi==1/Gi) probability of gene/variation belongs to perticular class
        # vec is 9 diamensional vector
        vec = []
        for k in range(1,10):
            # print(train_df.loc[(train_df['Class']==1) & (train_df['Gene']=='BRCA1')])
            #         ID   Gene             Variation  Class  
            # 2470  2470  BRCA1                S1715C      1   
            # 2486  2486  BRCA1                S1841R      1   
            # 2614  2614  BRCA1                   M1R      1   
            # 2432  2432  BRCA1                L1657P      1   
            # 2567  2567  BRCA1                T1685A      1   
            # 2583  2583  BRCA1                E1660G      1   
            # 2634  2634  BRCA1                W1718L      1   
            # cls_cnt.shape[0] will return the number of rows

            cls_cnt = train_df.loc[(train_df['Class']==k) & (train_df[feature]==i)]
            
            # cls_cnt.shape[0](numerator) will contain the number of time that particular feature occured in whole data
            vec.append((cls_cnt.shape[0] + alpha*10)/ (denominator + 90*alpha))

        # we are adding the gene/variation to the dict as key and vec as value
        gv_dict[i]=vec
    return gv_dict

# Get Gene variation feature
def get_gv_feature(alpha, feature, df):
    # print(gv_dict)
    #     {'BRCA1': [0.20075757575757575, 0.03787878787878788, 0.068181818181818177, 0.13636363636363635, 0.25, 0.19318181818181818, 0.03787878787878788, 0.03787878787878788, 0.03787878787878788], 
    #      'TP53': [0.32142857142857145, 0.061224489795918366, 0.061224489795918366, 0.27040816326530615, 0.061224489795918366, 0.066326530612244902, 0.051020408163265307, 0.051020408163265307, 0.056122448979591837], 
    #      'EGFR': [0.056818181818181816, 0.21590909090909091, 0.0625, 0.068181818181818177, 0.068181818181818177, 0.0625, 0.34659090909090912, 0.0625, 0.056818181818181816], 
    #      'BRCA2': [0.13333333333333333, 0.060606060606060608, 0.060606060606060608, 0.078787878787878782, 0.1393939393939394, 0.34545454545454546, 0.060606060606060608, 0.060606060606060608, 0.060606060606060608], 
    #      'PTEN': [0.069182389937106917, 0.062893081761006289, 0.069182389937106917, 0.46540880503144655, 0.075471698113207544, 0.062893081761006289, 0.069182389937106917, 0.062893081761006289, 0.062893081761006289], 
    #      'KIT': [0.066225165562913912, 0.25165562913907286, 0.072847682119205295, 0.072847682119205295, 0.066225165562913912, 0.066225165562913912, 0.27152317880794702, 0.066225165562913912, 0.066225165562913912], 
    #      'BRAF': [0.066666666666666666, 0.17999999999999999, 0.073333333333333334, 0.073333333333333334, 0.093333333333333338, 0.080000000000000002, 0.29999999999999999, 0.066666666666666666, 0.066666666666666666],
    #      ...
    #     }
    gv_dict = get_gv_fea_dict(alpha, feature, df)
    # value_count is similar in get_gv_fea_dict
    value_count = train_df[feature].value_counts()
    
    # gv_fea: Gene_variation feature, it will contain the feature for each feature value in the data
    gv_fea = []
    # for every feature values in the given data frame we will check if it is there in the train data then we will add the feature to gv_fea
    # if not we will add [1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9] to gv_fea
    for index, row in df.iterrows():
        if row[feature] in dict(value_count).keys():
            gv_fea.append(gv_dict[row[feature]])
        else:
            gv_fea.append([1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9])
#             gv_fea.append([-1,-1,-1,-1,-1,-1,-1,-1,-1])
    return gv_fea

# %% [markdown]
# when we caculate the probability of a feature belongs to any particular class, we apply laplace smoothing
# <li>(numerator + 10\*alpha) / (denominator + 90\*alpha) </li>

# %% [markdown]
# <h3>3.2.1 Univariate Analysis on Gene Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q1.</b> Gene, What type of feature it is ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Gene is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q2.</b> How many categories are there and How they are distributed?</p>

# %%
unique_genes = train_df['Gene'].value_counts()
print('Number of Unique Genes :', unique_genes.shape[0])
# the top 10 genes that occured most
print(unique_genes.head(10))
# Out:
# Number of Unique Genes : 231
# BRCA1     171
# TP53      105
# EGFR       92
# BRCA2      79
# PTEN       78
# KIT        71
# BRAF       66
# ALK        51
# ERBB2      42
# PIK3CA     38
# Name: Gene, dtype: int64

# %%
print("Ans: There are", unique_genes.shape[0] ,"different categories of genes in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 231 different categories of genes in the train data, and they are distibuted as follows

# %%
s = sum(unique_genes.values);
h = unique_genes.values/s;
plt.plot(h, label="Histrogram of Genes")
plt.xlabel('Index of a Gene')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
plt.plot(c,label='Cumulative distribution of Genes')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <p style="font-size:18px;"> <b>Q3.</b> How to featurize this Gene feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>there are two ways we can featurize this variable
# <ol><li>One hot Encoding</li><li>Response coding </li></ol></p>
# <p> We will choose the appropriate featurization based on the ML model we use.  For this problem of multi-class classification with categorical features, one-hot encoding is better for Logistic regression while response coding is better for Random Forests. </p>

# %%
#response-coding of the Gene feature
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", train_df))
# test gene feature
test_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", test_df))
# cross validation gene feature
cv_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", cv_df))

# %%
print("train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature:", train_gene_feature_responseCoding.shape)
# Out:
# train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature: (2124, 9)

# %%
# one-hot encoding of Gene feature.
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
gene_tfidfvectorizer = TfidfVectorizer()
train_gene_feature_onehotCoding = gene_tfidfvectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_tfidfvectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_tfidfvectorizer.transform(cv_df['Gene'])

# %%
print(train_gene_feature_onehotCoding.shape)
# Out:
# (2124, 234)

# %%
train_df['Gene'].head()
# Out:
# 1290     HRAS
# 1820     RHOA
# 724     ERBB2
# 2047     SOS1
# 490      TP53
# Name: Gene, dtype: object

# %%
gene_tfidfvectorizer.get_feature_names()
# Out:
# ['abl1',
#  'acvr1',
#  'ago2',
#  'akt1',
#  'akt2',
#  'akt3',
#  'alk',
#  'apc',
#  'ar',
#  'araf',
#  'arid1b',
#  'arid2',
#  'arid5b',
#  'asxl2',
#  'atm',
#  'atrx',
#  'aurka',
#  'aurkb',
#  'axin1',
#  'axl',
#  'b2m',
#  'bap1',
#  'bard1',
#  'bcl2l11',
#  'bcor',
#  'braf',
#  'brca1',
#  'brca2',
#  'brip1',
#  'btk',
#  'card11',
#  'carm1',
#  'casp8',
#  'cbl',
#  'ccnd1',
#  'ccnd2',
#  'ccnd3',
#  'ccne1',
#  'cdh1',
#  'cdk12',
#  'cdk4',
#  'cdk6',
#  'cdk8',
#  'cdkn1a',
#  'cdkn1b',
#  'cdkn2a',
#  'cdkn2b',
#  'cebpa',
#  'chek2',
#  'cic',
#  'crebbp',
#  'ctcf',
#  'ctla4',
#  'ctnnb1',
#  'ddr2',
#  'dicer1',
#  'dnmt3a',
#  'dnmt3b',
#  'dusp4',
#  'egfr',
#  'eif1ax',
#  'elf3',
#  'ep300',
#  'epas1',
#  'epcam',
#  'erbb2',
#  'erbb3',
#  'erbb4',
#  'ercc2',
#  'ercc3',
#  'ercc4',
#  'erg',
#  'esr1',
#  'etv1',
#  'etv6',
#  'ewsr1',
#  'ezh2',
#  'fam58a',
#  'fanca',
#  'fancc',
#  'fat1',
#  'fbxw7',
#  'fgf3',
#  'fgf4',
#  'fgfr1',
#  'fgfr2',
#  'fgfr3',
#  'fgfr4',
#  'flt1',
#  'flt3',
#  'foxa1',
#  'foxl2',
#  'foxo1',
#  'foxp1',
#  'gata3',
#  'gli1',
#  'gna11',
#  'gnaq',
#  'gnas',
#  'h3f3a',
#  'hnf1a',
#  'hras',
#  'idh1',
#  'idh2',
#  'igf1r',
#  'il7r',
#  'inpp4b',
#  'jak1',
#  'jak2',
#  'jun',
#  'kdm5c',
#  'kdm6a',
#  'kdr',
#  'keap1',
#  'kit',
#  'kmt2a',
#  'kmt2b',
#  'kmt2c',
#  'kmt2d',
#  'knstrn',
#  'kras',
#  'lats1',
#  'map2k1',
#  'map2k2',
#  'map2k4',
#  'map3k1',
#  'mdm4',
#  'med12',
#  'mef2b',
#  'men1',
#  'met',
#  'mga',
#  'mlh1',
#  'mpl',
#  'msh2',
#  'msh6',
#  'mtor',
#  'myc',
#  'myod1',
#  'ncor1',
#  'nf1',
#  'nf2',
#  'nfe2l2',
#  'nfkbia',
#  'nkx2',
#  'notch1',
#  'notch2',
#  'npm1',
#  'nras',
#  'nsd1',
#  'ntrk1',
#  'ntrk2',
#  'ntrk3',
#  'nup93',
#  'pak1',
#  'pax8',
#  'pbrm1',
#  'pdgfra',
#  'pdgfrb',
#  'pik3ca',
#  'pik3cb',
#  'pik3cd',
#  'pik3r1',
#  'pik3r2',
#  'pik3r3',
#  'pim1',
#  'pms2',
#  'pole',
#  'ppp2r1a',
#  'ppp6c',
#  'prdm1',
#  'ptch1',
#  'pten',
#  'ptpn11',
#  'ptprd',
#  'ptprt',
#  'rab35',
#  'rac1',
#  'rad21',
#  'rad50',
#  'rad51c',
#  'rad51d',
#  'rad54l',
#  'raf1',
#  'rara',
#  'rasa1',
#  'rb1',
#  'rbm10',
#  'ret',
#  'rheb',
#  'rhoa',
#  'rictor',
#  'rit1',
#  'rnf43',
#  'ros1',
#  'rras2',
#  'runx1',
#  'rybp',
#  'sdhb',
#  'sdhc',
#  'setd2',
#  'sf3b1',
#  'smad2',
#  'smad3',
#  'smad4',
#  'smarca4',
#  'smarcb1',
#  'smo',
#  'sos1',
#  'sox9',
#  'spop',
#  'src',
#  'srsf2',
#  'stag2',
#  'stat3',
#  'stk11',
#  'tcf3',
#  'tcf7l2',
#  'tert',
#  'tet1',
#  'tet2',
#  'tgfbr1',
#  'tgfbr2',
#  'tmprss2',
#  'tp53',
#  'tp53bp1',
#  'tsc1',
#  'tsc2',
#  'u2af1',
#  'vhl',
#  'whsc1',
#  'xpo1',
#  'xrcc2',
#  'yap1']

# %%
print("train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature:", train_gene_feature_onehotCoding.shape)
# Out:
# train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature: (2124, 234)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q4.</b> How good is this gene feature  in predicting y_i?</p>

# %% [markdown]
# There are many ways to estimate how good a feature is, in predicting y_i. One of the good methods is to build a proper ML model using just this feature. In this case, we will build a logistic regression model using only Gene feature (one hot encoded) to predict y_i.

# %%
alpha = [10 ** x for x in range(-5, 1)] # hyperparam for SGD classifier.
cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_gene_feature_onehotCoding, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_gene_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_gene_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_gene_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.3450535426670638
# For values of alpha =  0.0001 The log loss is: 1.1591568243038781
# For values of alpha =  0.001 The log loss is: 1.1774343375396592
# For values of alpha =  0.01 The log loss is: 1.296807944680084
# For values of alpha =  0.1 The log loss is: 1.390619136774993
# For values of alpha =  1 The log loss is: 1.4367164265849184
# For values of best alpha =  0.0001 The train log loss is: 1.0408438899347499
# For values of best alpha =  0.0001 The cross validation log loss is: 1.1591568243038781
# For values of best alpha =  0.0001 The test log loss is: 1.241501713359532

# %% [markdown]
# <p style="font-size:18px;"> <b>Q5.</b> Is the Gene feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it is. Otherwise, the CV and Test errors would be significantly more than train error. </p>

# %%
print("Q6. How many data points in Test and CV datasets are covered by the ", unique_genes.shape[0], " genes in train dataset?")

test_coverage=test_df[test_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]
cv_coverage=cv_df[cv_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]

print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q6. How many data points in Test and CV datasets are covered by the  234  genes in train dataset?
# Ans
# 1. In test data 649 out of 665 : 97.59398496240601
# 2. In cross validation data 510 out of  532 : 95.86466165413535

# %% [markdown]
# <h3>3.2.2 Univariate Analysis on Variation Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q7.</b> Variation, What type of feature is it ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Variation is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q8.</b> How many categories are there?</p>

# %%
unique_variations = train_df['Variation'].value_counts()
print('Number of Unique Variations :', unique_variations.shape[0])
# the top 10 variations that occured most
print(unique_variations.head(10))
# Out:
# Number of Unique Variations : 1928
# Truncating_Mutations    65
# Deletion                49
# Amplification           40
# Fusions                 17
# Overexpression           4
# E17K                     3
# Q61L                     3
# T58I                     3
# S308A                    2
# I31M                     2
# Name: Variation, dtype: int64

# %%
print("Ans: There are", unique_variations.shape[0] ,"different categories of variations in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 1928 different categories of variations in the train data, and they are distibuted as follows

# %%
s = sum(unique_variations.values);
h = unique_variations.values/s;
plt.plot(h, label="Histrogram of Variations")
plt.xlabel('Index of a Variation')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
print(c)
plt.plot(c,label='Cumulative distribution of Variations')
plt.grid()
plt.legend()
plt.show()
# Out:
# [0.03060264 0.05367232 0.07250471 ... 0.99905838 0.99952919 1.        ]

# %% [markdown]
# <p style="font-size:18px;"> <b>Q9.</b> How to featurize this Variation feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>There are two ways we can featurize this variable
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will be using both these methods to featurize the Variation Feature </p>

# %%
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", train_df))
# test gene feature
test_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", test_df))
# cross validation gene feature
cv_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", cv_df))

# %%
print("train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature:", train_variation_feature_responseCoding.shape)
# Out:
# train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature: (2124, 9)

# %%
# one-hot encoding of variation feature.
variation_tfidfvectorizer = TfidfVectorizer(max_features=1000)
train_variation_feature_onehotCoding = variation_tfidfvectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_tfidfvectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_tfidfvectorizer.transform(cv_df['Variation'])

# %%
print("train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature:", train_variation_feature_onehotCoding.shape)
# Out:
# train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature: (2124, 1000)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q10.</b> How good is this Variation feature  in predicting y_i?</p>

# %% [markdown]
# Let's build a model just like the earlier!

# %%
alpha = [10 ** x for x in range(-5, 1)]
cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_variation_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_variation_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
    
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_variation_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_variation_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.7216234494161682
# For values of alpha =  0.0001 The log loss is: 1.7132091804772132
# For values of alpha =  0.001 The log loss is: 1.7102291719544258
# For values of alpha =  0.01 The log loss is: 1.722195096667833
# For values of alpha =  0.1 The log loss is: 1.7363179642174984
# For values of alpha =  1 The log loss is: 1.7368627767593046
# For values of best alpha =  0.001 The train log loss is: 1.3997349892970028
# For values of best alpha =  0.001 The cross validation log loss is: 1.7102291719544258
# For values of best alpha =  0.001 The test log loss is: 1.7232843933666575

# %% [markdown]
# <p style="font-size:18px;"> <b>Q11.</b> Is the Variation feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Not sure! But lets be very sure using the below analysis. </p>

# %%
print("Q12. How many data points are covered by total ", unique_variations.shape[0], " genes in test and cross validation data sets?")
test_coverage=test_df[test_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
cv_coverage=cv_df[cv_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q12. How many data points are covered by total  1928  genes in test and cross validation data sets?
# Ans
# 1. In test data 68 out of 665 : 10.225563909774436
# 2. In cross validation data 55 out of  532 : 10.338345864661653

# %% [markdown]
# <h3>3.2.3 Univariate Analysis on Text Feature</h3>

# %% [markdown]
# 1. How many unique words are present in train data?
# 2. How are word frequencies distributed?
# 3. How to featurize text field?
# 4. Is the text feature useful in predicitng y_i?
# 5. Is the text feature stable across train, test and CV datasets?

# %%
# cls_text is a data frame
# for every row in data fram consider the 'TEXT'
# split the words by space
# make a dict with those words
# increment its count whenever we see that word

def extract_dictionary_paddle(cls_text):
    dictionary = defaultdict(int)
    for index, row in cls_text.iterrows():
        for word in row['TEXT'].split():
            dictionary[word] +=1
    return dictionary

# %%
import math
#https://stackoverflow.com/a/1602964
def get_text_responsecoding(df):
    text_feature_responseCoding = np.zeros((df.shape[0],9))
    for i in range(0,9):
        row_index = 0
        for index, row in df.iterrows():
            sum_prob = 0
            for word in row['TEXT'].split():
                sum_prob += math.log(((dict_list[i].get(word,0)+10 )/(total_dict.get(word,0)+90)))
            text_feature_responseCoding[row_index][i] = math.exp(sum_prob/len(row['TEXT'].split()))
            row_index += 1
    return text_feature_responseCoding

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_Tfidfvectorizer = TfidfVectorizer(min_df=3, max_features=1000)
train_text_feature_onehotCoding = text_Tfidfvectorizer.fit_transform(train_df['TEXT'])
test_text_feature_onehotCoding = text_Tfidfvectorizer.transform(test_df['TEXT'])
cv_text_feature_onehotCoding = text_Tfidfvectorizer.transform(cv_df['TEXT'])
# getting all the feature names (words)
train_text_features= text_Tfidfvectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 1000

# %%
dict_list = []
# dict_list =[] contains 9 dictoinaries each corresponds to a class
for i in range(1,10):
    cls_text = train_df[train_df['Class']==i]
    # build a word dict based on the words in that class
    dict_list.append(extract_dictionary_paddle(cls_text))
    # append it to dict_list

# dict_list[i] is build on i'th  class text data
# total_dict is buid on whole training text data
total_dict = extract_dictionary_paddle(train_df)


confuse_array = []
for i in train_text_features:
    ratios = []
    max_val = -1
    for j in range(0,9):
        ratios.append((dict_list[j][i]+10 )/(total_dict[i]+90))
    confuse_array.append(ratios)
confuse_array = np.array(confuse_array)

# %%
#response coding of text features
train_text_feature_responseCoding  = get_text_responsecoding(train_df)
test_text_feature_responseCoding  = get_text_responsecoding(test_df)
cv_text_feature_responseCoding  = get_text_responsecoding(cv_df)

# %%
# we convert each row values such that they sum to 1  
train_text_feature_responseCoding = (train_text_feature_responseCoding.T/train_text_feature_responseCoding.sum(axis=1)).T
test_text_feature_responseCoding = (test_text_feature_responseCoding.T/test_text_feature_responseCoding.sum(axis=1)).T
cv_text_feature_responseCoding = (cv_text_feature_responseCoding.T/cv_text_feature_responseCoding.sum(axis=1)).T

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
#test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
#cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
sorted_text_fea_dict = dict(sorted(text_fea_dict.items(), key=lambda x: x[1] , reverse=True))
sorted_text_occur = np.array(list(sorted_text_fea_dict.values()))

# %%
# Number of words for a given frequency.
print(Counter(sorted_text_occur))
# Out:
# Counter({257.98484311933345: 1, 177.60773213742124: 1, 138.4841946831576: 1, 132.7124115671468: 1, 129.18416099084826: 1, 117.43332159913494: 1, 116.6807292751656: 1, 116.24437748503436: 1, 107.82413723149583: 1, 107.06831526501362: 1, 105.59935566127932: 1, 89.01917266167011: 1, 88.61980171769139: 1, 84.35538174114129: 1, 80.36683002655212: 1, 78.46661115250826: 1, 78.39047093313978: 1, 78.34181675165387: 1, 76.6238007192814: 1, 76.44356339403768: 1, 74.6339788977595: 1, 71.4380502225536: 1, 70.62075780091035: 1, 70.27893650511344: 1, 68.08215977770543: 1, 65.46805131433018: 1, 64.5908363254654: 1, 64.54550568854239: 1, 64.38637649900888: 1, 63.67500183300984: 1, 63.5112971483908: 1, 63.32493215409361: 1, 61.98438767996048: 1, 60.64088824045866: 1, 59.37786611175938: 1, 58.98483044839952: 1, 58.55943940002063: 1, 57.03631300216088: 1, 56.42101228061165: 1, 54.22796536980303: 1, 52.057490242632674: 1, 50.96967002599256: 1, 49.68220267428841: 1, 49.36698681684951: 1, 48.81278975097665: 1, 47.67493171684958: 1, 47.16018988731655: 1, 45.57274969310919: 1, 45.42582644070829: 1, 45.10263520820391: 1, 44.95735161725055: 1, 44.40057901037344: 1, 44.01198854272299: 1, 43.74089966190633: 1, 43.47643160492208: 1, 42.93600739465477: 1, 42.37507442647006: 1, 42.034847110900486: 1, 41.94946368783077: 1, 41.68794772834644: 1, 41.13066975349685: 1, 41.12774709884282: 1, 41.11923606559104: 1, 41.09999023530031: 1, 40.97102774356269: 1, 40.966833582118284: 1, 40.93079568148719: 1, 40.54307141516701: 1, 40.0417178238908: 1, 39.473270810355444: 1, 39.22062579366452: 1, 38.92322336089966: 1, 38.20151861282722: 1, 37.99766768272605: 1, 37.87641116210719: 1, 37.679965426813844: 1, 37.575079124646884: 1, 37.18806470212262: 1, 36.7757590720446: 1, 35.74249088855044: 1, 35.56478743134515: 1, 35.10123841482399: 1, 34.85177012779702: 1, 34.75424605045659: 1, 34.728936414951114: 1, 34.619011146811204: 1, 34.30689021593786: 1, 34.201009586745485: 1, 34.19925811027372: 1, 33.837620551464475: 1, 33.780302045028975: 1, 33.5172492921789: 1, 33.12516676670785: 1, 32.843175476861816: 1, 32.696641493413786: 1, 32.679392973425664: 1, 32.5933983162478: 1, 32.473676443578626: 1, 32.36172638035416: 1, 32.196042897038126: 1, 32.180389492242846: 1, 32.02812024393034: 1, 31.88598509125134: 1, 31.80471460259848: 1, 31.61602118472071: 1, 31.58540279321153: 1, 31.490558966060195: 1, 31.433184242545018: 1, 31.18955760956573: 1, 31.16703370880817: 1, 31.125740162255575: 1, 31.101992233723344: 1, 31.06573620333454: 1, 30.82614406431026: 1, 30.60134081716977: 1, 30.505811592707794: 1, 30.49449821695812: 1, 30.37225047155674: 1, 30.270651682503463: 1, 30.26343303612344: 1, 30.1793642574563: 1, 30.14508046380944: 1, 29.834360395448414: 1, 29.75347116817261: 1, 29.34932514127438: 1, 29.262239199665153: 1, 29.220486610190868: 1, 29.054724659036967: 1, 29.045482145203845: 1, 28.5985436852174: 1, 28.377936301242073: 1, 28.321508978266284: 1, 28.296626835297918: 1, 27.824762215807343: 1, 27.64504148903654: 1, 27.593084649479906: 1, 27.42225373709516: 1, 27.385017124032185: 1, 27.367341339281836: 1, 26.968683473251442: 1, 26.915960322104013: 1, 26.80782110963529: 1, 26.55096970318069: 1, 26.528534865677713: 1, 26.361905817967575: 1, 26.23838229232882: 1, 26.23062236606639: 1, 26.14712673808237: 1, 26.039710037227945: 1, 25.90238203164455: 1, 25.632253413727156: 1, 25.484525808430064: 1, 25.46128069493867: 1, 25.357545875677236: 1, 25.232109025890317: 1, 25.160389408319286: 1, 25.125518414325867: 1, 25.097269171891405: 1, 24.998657375144287: 1, 24.959564142823254: 1, 24.854743414547695: 1, 24.691461878801867: 1, 24.66232673217598: 1, 24.603816164732663: 1, 24.56687317919117: 1, 24.467463461799333: 1, 24.401450175360523: 1, 24.353247466993043: 1, 24.3524885800094: 1, 24.28984816791575: 1, 24.271680729456307: 1, 24.15658295360554: 1, 24.125042785818742: 1, 24.093867060468444: 1, 23.99696246470649: 1, 23.96766712957921: 1, 23.91218769001402: 1, 23.678234120293272: 1, 23.593362879394988:  ...

# %%
# Train a Logistic regression+Calibration model using text features whicha re on-hot encoded
alpha = [10 ** x for x in range(-5, 1)]
cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_text_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_text_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_text_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_text_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.0895665411520294
# For values of alpha =  0.0001 The log loss is: 1.1210725687319003
# For values of alpha =  0.001 The log loss is: 1.4236236579466532
# For values of alpha =  0.01 The log loss is: 2.046145736041282
# For values of alpha =  0.1 The log loss is: 2.0890976370873973
# For values of alpha =  1 The log loss is: 2.0661443978232037
# For values of best alpha =  1e-05 The train log loss is: 0.735662109537889
# For values of best alpha =  1e-05 The cross validation log loss is: 1.0895665411520294
# For values of best alpha =  1e-05 The test log loss is: 1.2202217049773716

# %% [markdown]
# <p style="font-size:18px;"> <b>Q.</b> Is the Text feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it seems like! </p>

# %%
def get_intersec_text(df):
    df_text_tfidfvec = TfidfVectorizer(min_df=3,max_features=1000)
    df_text_fea = df_text_tfidfvec.fit_transform(df['TEXT'])
    df_text_features = df_text_tfidfvec.get_feature_names()

    df_text_fea_counts = df_text_fea.sum(axis=0).A1
    df_text_fea_dict = dict(zip(list(df_text_features),df_text_fea_counts))
    len1 = len(set(df_text_features))
    len2 = len(set(train_text_features) & set(df_text_features))
    return len1,len2

# %%
len1,len2 = get_intersec_text(test_df)
print(np.round((len2/len1)*100, 3), "% of word of test data appeared in train data")
len1,len2 = get_intersec_text(cv_df)
print(np.round((len2/len1)*100, 3), "% of word of Cross Validation appeared in train data")
# Out:
# 94.9 % of word of test data appeared in train data
# 93.6 % of word of Cross Validation appeared in train data

# %% [markdown]
# <h1>4. Machine Learning Models</h1>

# %%
#Data preparation for ML models.

#Misc. functionns for ML models


def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    plot_confusion_matrix(test_y, pred_y)

# %%
def report_log_loss(train_x, train_y, test_x, test_y,  clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    sig_clf_probs = sig_clf.predict_proba(test_x)
    return log_loss(test_y, sig_clf_probs, eps=1e-15)

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = TfidfVectorizer(max_features=1000)
    var_count_vec = TfidfVectorizer(max_features=1000)
    text_count_vec = TfidfVectorizer(min_df=3,max_features=1000)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))


train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (2124, 2234)
# (number of data points * number of features) in test data =  (665, 2234)
# (number of data points * number of features) in cross validation data = (532, 2234)

# %%
print(" Response encoding features :")
print("(number of data points * number of features) in train data = ", train_x_responseCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_responseCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_responseCoding.shape)
# Out:
#  Response encoding features :
# (number of data points * number of features) in train data =  (2124, 27)
# (number of data points * number of features) in test data =  (665, 27)
# (number of data points * number of features) in cross validation data = (532, 27)

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)


predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.1462387453941703
# for alpha = 0.0001
# Log Loss : 1.1455894522610859
# for alpha = 0.001
# Log Loss : 1.1437394736859132
# for alpha = 0.1
# Log Loss : 1.170118585608204
# for alpha = 1
# Log Loss : 1.1907453066156362
# for alpha = 10
# Log Loss : 1.3279835817768244
# for alpha = 100
# Log Loss : 1.3343814949239907
# for alpha = 1000
# Log Loss : 1.3347187044073723
# For values of best alpha =  0.001 The train log loss is: 0.7559994217863876
# For values of best alpha =  0.001 The cross validation log loss is: 1.1437394736859132
# For values of best alpha =  0.001 The test log loss is: 1.2218194071450807

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding.toarray()))
# Out:
# Log Loss : 1.1437394736859132
# Number of missclassified point : 0.39473684210526316
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, Correctly classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.5291 0.0515 0.0163 0.2344 0.0378 0.0404 0.0816 0.0047 0.0042]]
# Actual Class : 1
# --------------------------------------------------
# 9 Text feature [one] present in test data point [True]
# 11 Text feature [function] present in test data point [True]
# 12 Text feature [protein] present in test data point [True]
# 13 Text feature [two] present in test data point [True]
# 14 Text feature [results] present in test data point [True]
# 15 Text feature [dna] present in test data point [True]
# 16 Text feature [table] present in test data point [True]
# 17 Text feature [role] present in test data point [True]
# 18 Text feature [also] present in test data point [True]
# 19 Text feature [loss] present in test data point [True]
# 20 Text feature [type] present in test data point [True]
# 21 Text feature [possible] present in test data point [True]
# 22 Text feature [therefore] present in test data point [True]
# 23 Text feature [however] present in test data point [True]
# 24 Text feature [either] present in test data point [True]
# 25 Text feature [region] present in test data point [True]
# 26 Text feature [may] present in test data point [True]
# 30 Text feature [determined] present in test data point [True]
# 31 Text feature [wild] present in test data point [True]
# 32 Text feature [involved] present in test data point [True]
# 33 Text feature [using] present in test data point [True]
# 34 Text feature [binding] present in test data point [True]
# 35 Text feature [large] present in test data point [True]
# 37 Text feature [containing] present in test data point [True]
# 38 Text feature [gene] present in test data point [True]
# 39 Text feature [well] present in test data point [True]
# 40 Text feature [human] present in test data point [True]
# 41 Text feature [three] present in test data point [True]
# 42 Text feature [25] present in test data point [True]
# 44 Text feature [including] present in test data point [True]
# 46 Text feature [important] present in test data point [True]
# 47 Text feature [four] present in test data point [True]
# 51 Text feature [shown] present in test data point [True]
# 52 Text feature [used] present in test data point [True]
# 54 Text feature [least] present in test data point [True]
# 55 Text feature [discussion] present in test data point [True]
# 57 Text feature [specific] present in test data point [True]
# 58 Text feature [within] present in test data point [True]
# 59 Text feature [proteins] present in test data point [True]
# 65 Text feature [observed] present in test data point [True]
# 67 Text feature [analysis] present in test data point [True]
# 68 Text feature [data] present in test data point [True]
# 69 Text feature [although] present in test data point [True]
# 70 Text feature [compared] present in test data point [True]
# 71 Text feature [30] present in test data point [True]
# 73 Text feature [different] present in test data point [True]
# 76 Text feature [similar] present in test data point [True]
# 77 Text feature [associated] present in test data point [True]
# 78 Text feature [performed] present in test data point [True]
# 79 Text feature [based] present in test data point [True]
# 80 Text feature [together] present in test data point [True]
# 82 Text feature [identify] present in test data point [True]
# 83 Text feature [addition] present in test data point [True]
# 85 Text feature [previous] present in test data point [True]
# 86 Text feature [previously] present in test data point [True]
# 87 Text feature [present] present in test data point [True]
# 89 Text feature [whereas] present in test data point [True]
# 90 Text feature [significant] present in test data point [True]
# 92 Text feature [fig] present in test data point [True]
# 93 Text feature [cancer] present in test data point [True]
# 94 Text feature [mutations] present in test data point [True]
# 95 Text feature [several] present in test data point [True]
# 96 Text feature [significantly] present in test data point [True]
# 97 Text feature [mutation] present in test data point [True]
# 99 Text feature [genes] present in test data point [True]
# Out of the top  100  features  65 are present in query point

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0587 0.0748 0.0151 0.059  0.0352 0.0363 0.7125 0.0044 0.0039]]
# Actual Class : 2
# --------------------------------------------------
# 15 Text feature [activation] present in test data point [True]
# 17 Text feature [activated] present in test data point [True]
# 18 Text feature [downstream] present in test data point [True]
# 19 Text feature [kinase] present in test data point [True]
# 23 Text feature [inhibitor] present in test data point [True]
# 24 Text feature [cells] present in test data point [True]
# 25 Text feature [expressing] present in test data point [True]
# 26 Text feature [growth] present in test data point [True]
# 27 Text feature [independent] present in test data point [True]
# 28 Text feature [signaling] present in test data point [True]
# 29 Text feature [activating] present in test data point [True]
# 31 Text feature [contrast] present in test data point [True]
# 32 Text feature [previously] present in test data point [True]
# 33 Text feature [10] present in test data point [True]
# 34 Text feature [constitutive] present in test data point [True]
# 35 Text feature [sensitive] present in test data point [True]
# 36 Text feature [also] present in test data point [True]
# 37 Text feature [well] present in test data point [True]
# 38 Text feature [however] present in test data point [True]
# 39 Text feature [addition] present in test data point [True]
# 40 Text feature [factor] present in test data point [True]
# 41 Text feature [treated] present in test data point [True]
# 42 Text feature [compared] present in test data point [True]
# 43 Text feature [treatment] present in test data point [True]
# 44 Text feature [inhibitors] present in test data point [True]
# 45 Text feature [cell] present in test data point [True]
# 46 Text feature [mutations] present in test data point [True]
# 47 Text feature [presence] present in test data point [True]
# 48 Text feature [phosphorylation] present in test data point [True]
# 49 Text feature [higher] present in test data point [True]
# 50 Text feature [3b] present in test data point [True]
# 51 Text feature [shown] present in test data point [True]
# 52 Text feature [increased] present in test data point [True]
# 53 Text feature [similar] present in test data point [True]
# 54 Text feature [may] present in test data point [True]
# 55 Text feature [potential] present in test data point [True]
# 56 Text feature [inhibition] present in test data point [True]
# 57 Text feature [oncogenic] present in test data point [True]
# 61 Text feature [suggest] present in test data point [True]
# 62 Text feature [found] present in test data point [True]
# 64 Text feature [proliferation] present in test data point [True]
# 65 Text feature [figure] present in test data point [True]
# 66 Text feature [3a] present in test data point [True]
# 67 Text feature [recently] present in test data point [True]
# 68 Text feature [mutant] present in test data point [True]
# 69 Text feature [showed] present in test data point [True]
# 70 Text feature [pathways] present in test data point [True]
# 71 Text feature [absence] present in test data point [True]
# 72 Text feature [constitutively] present in test data point [True]
# 73 Text feature [mechanism] present in test data point [True]
# 74 Text feature [consistent] present in test data point [True]
# 75 Text feature [mutation] present in test data point [True]
# 76 Text feature [survival] present in test data point [True]
# 77 Text feature [although] present in test data point [True]
# 78 Text feature [enhanced] present in test data point [True]
# 79 Text feature [tyrosine] present in test data point [True]
# 80 Text feature [total] present in test data point [True]
# 81 Text feature [described] present in test data point [True]
# 82 Text feature [12] present in test data point [True]
# 83 Text feature [receptor] present in test data point [True]
# 84 Text feature [reported] present in test data point [True]
# 85 Text feature [without] present in test data point [True]
# 87 Text feature [effective] present in test data point [True]
# 88 Text feature [observed] present in test data point [True]
# 89 Text feature [20] present in test data point [True]
# 90 Text feature [using] present in test data point [True]
# 91 Text feature [results] present in test data point [True]
# 92 Text feature [therapeutic] present in test data point [True]
# 93 Text feature [pathway] present in test data point [True]
# 94 Text feature [2b] present in test data point [True]
# 95 Text feature [respectively] present in test data point [True]
# 96 Text feature [interestingly] present in test data point [True]
# 97 Text feature [24] present in test data point [True]
# 98 Text feature [different] present in test data point [True]
# 99 Text feature [13] present in test data point [True]
# Out of the top  100  features  75 are present in query point

# %% [markdown]
# <h2>4.2. K Nearest Neighbour Classification</h2>

# %% [markdown]
# <h3>4.2.1. Hyper parameter tuning</h3>

# %%
alpha = [5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(train_x_responseCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_responseCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 5
# Log Loss : 0.9997565984492267
# for alpha = 11
# Log Loss : 0.985937107996683
# for alpha = 15
# Log Loss : 0.987404347112772
# for alpha = 21
# Log Loss : 1.004536538976032
# for alpha = 31
# Log Loss : 1.0258546067650947
# for alpha = 41
# Log Loss : 1.0327971891343855
# for alpha = 51
# Log Loss : 1.0435145268316073
# for alpha = 99
# Log Loss : 1.0984996035199739
# For values of best alpha =  11 The train log loss is: 0.6213529454583038
# For values of best alpha =  11 The cross validation log loss is: 0.985937107996683
# For values of best alpha =  11 The test log loss is: 1.0989737037776806

# %% [markdown]
# <h3>4.2.2. Testing the model with best hyper paramters</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y, cv_x_responseCoding, cv_y, clf)
# Out:
# Log loss : 0.985937107996683
# Number of mis-classified points : 0.35714285714285715
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.2.3.Sample Query point -1</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 1
predicted_cls = sig_clf.predict(test_x_responseCoding[0].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 1
# The  11  nearest neighbours of the test points belongs to classes [1 4 3 4 4 3 1 1 4 4 4]
# Fequency of nearest points : Counter({4: 6, 1: 3, 3: 2})

# %% [markdown]
# <h3>4.2.4. Sample Query Point-2 </h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 100

predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("the k value for knn is",alpha[best_alpha],"and the nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 2
# the k value for knn is 11 and the nearest neighbours of the test points belongs to classes [7 2 7 7 7 7 7 7 7 7 7]
# Fequency of nearest points : Counter({7: 10, 2: 1})

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning</h4>

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.099102908000765
# for alpha = 1e-05
# Log Loss : 1.057186626694597
# for alpha = 0.0001
# Log Loss : 0.9556652641863917
# for alpha = 0.001
# Log Loss : 0.9957273135191694
# for alpha = 0.01
# Log Loss : 1.218039317900356
# for alpha = 0.1
# Log Loss : 1.628475632497093
# for alpha = 1
# Log Loss : 1.7748501128432108
# for alpha = 10
# Log Loss : 1.7937974194562112
# for alpha = 100
# Log Loss : 1.7959953947225065
# For values of best alpha =  0.0001 The train log loss is: 0.5693921914565699
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9556652641863917
# For values of best alpha =  0.0001 The test log loss is: 1.0284467053895963

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 0.9556652641863917
# Number of mis-classified points : 0.3308270676691729
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.6801 0.0165 0.003  0.1755 0.0062 0.1061 0.0036 0.0064 0.0027]]
# Actual Class : 1
# --------------------------------------------------
# 9 Text feature [hotspots] present in test data point [True]
# 21 Text feature [surface] present in test data point [True]
# 28 Text feature [hydrophobic] present in test data point [True]
# 85 Text feature [identify] present in test data point [True]
# 106 Text feature [strand] present in test data point [True]
# 112 Text feature [position] present in test data point [True]
# 119 Text feature [function] present in test data point [True]
# 122 Text feature [molecules] present in test data point [True]
# 136 Text feature [box] present in test data point [True]
# 138 Text feature [pa] present in test data point [True]
# 150 Text feature [encoding] present in test data point [True]
# 157 Text feature [region] present in test data point [True]
# 199 Text feature [loss] present in test data point [True]
# 200 Text feature [structure] present in test data point [True]
# 212 Text feature [specificity] present in test data point [True]
# 214 Text feature [possible] present in test data point [True]
# 222 Text feature [complex] present in test data point [True]
# 224 Text feature [interact] present in test data point [True]
# 229 Text feature [biological] present in test data point [True]
# 237 Text feature [complexes] present in test data point [True]
# 240 Text feature [crystal] present in test data point [True]
# 245 Text feature [calculated] present in test data point [True]
# 246 Text feature [sample] present in test data point [True]
# 249 Text feature [analyses] present in test data point [True]
# 253 Text feature [vivo] present in test data point [True]
# 255 Text feature [population] present in test data point [True]
# 258 Text feature [interestingly] present in test data point [True]
# 259 Text feature [nucleotide] present in test data point [True]
# 275 Text feature [hotspot] present in test data point [True]
# 285 Text feature [wild] present in test data point [True]
# 288 Text feature [one] present in test data point [True]
# 302 Text feature [side] present in test data point [True]
# 307 Text feature [peptide] present in test data point [True]
# 309 Text feature [directed] present in test data point [True]
# 312 Text feature [role] present in test data point [True]
# 315 Text feature [located] present in test data point [True]
# 318 Text feature [interactions] present in test data point [True]
# 321 Text feature [type] present in test data point [True]
# 323 Text feature [regulatory] present in test data point [True]
# 324 Text feature [frequency] present in test data point [True]
# 325 Text feature [binding] present in test data point [True]
# 326 Text feature [line] present in test data point [True]
# 328 Text feature [tagged] present in test data point [True]
# 330 Text feature [domains] present in test data point [True]
# 332 Text feature [30] present in test data point [True]
# 338 Text feature [dependent] present in test data point [True]
# 340 Text feature [residue] present in test data point [True]
# 344 Text feature [furthermore] present in test data point [True]
# 349 Text feature [sequencing] present in test data point [True]
# 351 Text feature [100] present in test data point [True]
# 357 Text feature [therefore] present in test data point [True]
# 372 Text feature [cell] present in test data point [True]
# 378 Text feature [large] present in test data point [True]
# 379 Text feature [among] present in test data point [True]
# 382 Text feature [1997] present in test data point [True]
# 384 Text feature [previous] present in test data point [True]
# 387 Text feature [involved] present in test data point [True]
# 388 Text feature [added] present in test data point [True]
# 389 Text feature [determined] present in test data point [True]
# 392 Text feature [codon] present in test data point [True]
# 395 Text feature [table] present in test data point [True]
# 399 Text feature [containing] present in test data point [True]
# 400 Text feature [based] present in test data point [True]
# 401 Text feature [least] present in test data point [True]
# 402 Text feature [mutagenesis] present in test data point [True]
# 404 Text feature [within] present in test data point [True]
# 408 Text feature [present] present in test data point [True]
# 422 Text feature [structures] present in test data point [True]
# 424 Text feature [54] present in test data point [True]
# 427 Text feature [structural] present in test data point [True]
# 430 Text feature [conditions] present in test data point [True]
# 431 Text feature [subunit] present in test data point [True]
# 436 Text feature [2008] present in test data point [True]
# 437 Text feature [significantly] present in test data point [True]
# 439 Text feature [mean] present in test data point [True]
# 441 Text feature [dna] present in test data point [True]
# 442 Text feature [reverse] present in test data point [True]
# 443 Text feature [fig] present in test data point [True]
# 444 Text feature [25] present in test data point [True]
# 454 Text feature [proteins] present in test data point [True]
# 460 Text feature [major] present in test data point [True]
# 462 Text feature [protein] present in test data point [True]
# 465 Text feature [observed] present in test data point [True]
# 470 Text feature [available] present in test data point [True]
# 471 Text feature [primers] present in test data point [True]
# 474 Text feature [either] present in test data point [True]
# 477 Text feature [reported] present in test data point [True]
# 485 Text feature [transcription] present in test data point [True]
# 487 Text feature [contains] present in test data point [True]
# 497 Text feature [appears] present in test data point [True]
# Out of the top  500  features  90 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0033 0.2165 0.017  0.0008 0.0142 0.0297 0.7128 0.0048 0.0009]]
# Actual Class : 2
# --------------------------------------------------
# 9 Text feature [oncogene] present in test data point [True]
# 10 Text feature [overexpression] present in test data point [True]
# 14 Text feature [activation] present in test data point [True]
# 16 Text feature [enhanced] present in test data point [True]
# 19 Text feature [transformed] present in test data point [True]
# 20 Text feature [3b] present in test data point [True]
# 23 Text feature [ligand] present in test data point [True]
# 26 Text feature [downstream] present in test data point [True]
# 30 Text feature [constitutive] present in test data point [True]
# 32 Text feature [transforming] present in test data point [True]
# 34 Text feature [activated] present in test data point [True]
# 50 Text feature [specimens] present in test data point [True]
# 62 Text feature [advanced] present in test data point [True]
# 64 Text feature [activating] present in test data point [True]
# 65 Text feature [ras] present in test data point [True]
# 66 Text feature [membrane] present in test data point [True]
# 70 Text feature [epithelial] present in test data point [True]
# 76 Text feature [pathways] present in test data point [True]
# 79 Text feature [inhibited] present in test data point [True]
# 83 Text feature [previously] present in test data point [True]
# 88 Text feature [akt] present in test data point [True]
# 92 Text feature [extracellular] present in test data point [True]
# 94 Text feature [observations] present in test data point [True]
# 95 Text feature [provided] present in test data point [True]
# 111 Text feature [adenocarcinoma] present in test data point [True]
# 112 Text feature [cdna] present in test data point [True]
# 119 Text feature [examined] present in test data point [True]
# 124 Text feature [2b] present in test data point [True]
# 125 Text feature [size] present in test data point [True]
# 126 Text feature [3t3] present in test data point [True]
# 131 Text feature [2a] present in test data point [True]
# 139 Text feature [mechanisms] present in test data point [True]
# 140 Text feature [factor] present in test data point [True]
# 141 Text feature [inhibitor] present in test data point [True]
# 144 Text feature [signaling] present in test data point [True]
# 152 Text feature [derived] present in test data point [True]
# 153 Text feature [express] present in test data point [True]
# 158 Text feature [72] present in test data point [True]
# 164 Text feature [colony] present in test data point [True]
# 165 Text feature [expressing] present in test data point [True]
# 169 Text feature [approximately] present in test data point [True]
# 170 Text feature [blood] present in test data point [True]
# 176 Text feature [cancers] present in test data point [True]
# 192 Text feature [concentrations] present in test data point [True]
# 195 Text feature [days] present in test data point [True]
# 204 Text feature [promote] present in test data point [True]
# 205 Text feature [nsclc] present in test data point [True]
# 207 Text feature [driven] present in test data point [True]
# 208 Text feature [position] present in test data point [True]
# 219 Text feature [biological] present in test data point [True]
# 221 Text feature [61] present in test data point [True]
# 224 Text feature [3a] present in test data point [True]
# 225 Text feature [survival] present in test data point [True]
# 226 Text feature [tyrosine] present in test data point [True]
# 228 Text feature [versus] present in test data point [True]
# 232 Text feature [properties] present in test data point [True]
# 233 Text feature [leading] present in test data point [True]
# 235 Text feature [increased] present in test data point [True]
# 237 Text feature [proliferation] present in test data point [True]
# 241 Text feature [responses] present in test data point [True]
# 247 Text feature [leukemia] present in test data point [True]
# 249 Text feature [conditions] present in test data point [True]
# 251 Text feature [oncogenic] present in test data point [True]
# 252 Text feature [lung] present in test data point [True]
# 254 Text feature [form] present in test data point [True]
# 259 Text feature [increase] present in test data point [True]
# 260 Text feature [standard] present in test data point [True]
# 262 Text feature [genomic] present in test data point [True]
# 268 Text feature [frequent] present in test data point [True]
# 273 Text feature [demonstrated] present in test data point [True]
# 276 Text feature [myeloid] present in test data point [True]
# 280 Text feature [common] present in test data point [True]
# 284 Text feature [carcinoma] present in test data point [True]
# 286 Text feature [culture] present in test data point [True]
# 288 Text feature [mutant] present in test data point [True]
# 290 Text feature [bp] present in test data point [True]
# 295 Text feature [stat3] present in test data point [True]
# 297 Text feature [leads] present in test data point [True]
# 305 Text feature [nm] present in test data point [True]
# 308 Text feature [egfr] present in test data point [True]
# 311 Text feature [involving] present in test data point [True]
# 318 Text feature [signals] present in test data point [True]
# 322 Text feature [download] present in test data point [True]
# 324 Text feature [sites] present in test data point [True]
# 329 Text feature [factors] present in test data point [True]
# 331 Text feature [free] present in test data point [True]
# 332 Text feature [potent] present in test data point [True]
# 337 Text feature [receptors] present in test data point [True]
# 338 Text feature [positive] present in test data point [True]
# 340 Text feature [presence] present in test data point [True]
# 346 Text feature [egf] present in test data point [True]
# 348 Text feature [absence] present in test data point [True]
# 352 Text feature [stage] present in test data point [True]
# 354 Text feature [tissues] present in test data point [True]
# 356 Text feature [51] present in test data point [True]
# 357 Text feature [comparison] present in test data point [True]
# 365 Text feature [sirna] present in test data point [True]
# 371 Text feature [progression] present in test data point [True]
# 372 Text feature [gefitinib] present in test data point [True]
# 373 Text feature [include] present in test data point [True]
# 384 Text feature [brain] present in test data point [True]
# 387 Text feature [75] present in test data point [True]
# 389 Text feature [harboring] present in test data point [True]
# 397 Text feature [addition] present in test data point [True]
# 399 Text feature [total] present in test data point [True]
# 403 Text feature [prior] present in test data point [True]
# 404 Text feature [example] present in test data point [True]
# 412 Text feature [regulated] present in test data point [True]
# 413 Text feature [4a] present in test data point [True]
# 414 Text feature [furthermore] present in test data point [True]
# 416 Text feature [phosphorylation] present in test data point [True]
# 419 Text feature [high] present in test data point [True]
# 421 Text feature [contribute] present in test data point [True]
# 423 Text feature [distinct] present in test data point [True]
# 425 Text feature [000] present in test data point [True]
# 426 Text feature [14] present in test data point [True]
# 427 Text feature [transformation] present in test data point [True]
# 428 Text feature [transcription] present in test data point [True]
# 429 Text feature [independent] present in test data point [True]
# 435 Text feature [52] present in test data point [True]
# 438 Text feature [note] present in test data point [True]
# 440 Text feature [interestingly] present in test data point [True]
# 441 Text feature [sensitive] present in test data point [True]
# 442 Text feature [pi3k] present in test data point [True]
# 444 Text feature [use] present in test data point [True]
# 448 Text feature [upon] present in test data point [True]
# 459 Text feature [cyclin] present in test data point [True]
# 460 Text feature [kinases] present in test data point [True]
# 462 Text feature [vector] present in test data point [True]
# 467 Text feature [introduction] present in test data point [True]
# 469 Text feature [fusions] present in test data point [True]
# 470 Text feature [somatic] present in test data point [True]
# 471 Text feature [substitution] present in test data point [True]
# 477 Text feature [region] present in test data point [True]
# 478 Text feature [effective] present in test data point [True]
# 480 Text feature [corresponding] present in test data point [True]
# 484 Text feature [49] present in test data point [True]
# 490 Text feature [chain] present in test data point [True]
# 491 Text feature [mechanism] present in test data point [True]
# 493 Text feature [prostate] present in test data point [True]
# 497 Text feature [cells] present in test data point [True]
# Out of the top  500  features  141 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1097715813457378
# for alpha = 1e-05
# Log Loss : 1.080720965734999
# for alpha = 0.0001
# Log Loss : 0.9971892692739905
# for alpha = 0.001
# Log Loss : 1.0887456689273933
# for alpha = 0.01
# Log Loss : 1.4306149790988278
# for alpha = 0.1
# Log Loss : 1.8596474517299548
# for alpha = 1
# Log Loss : 1.9249541067246982
# For values of best alpha =  0.0001 The train log loss is: 0.5619782759176478
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9971892692739905
# For values of best alpha =  0.0001 The test log loss is: 1.0523628730578767

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 0.9971892692739905
# Number of mis-classified points : 0.33458646616541354
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.6687 0.0184 0.0015 0.2031 0.0046 0.0868 0.0069 0.0091 0.0008]]
# Actual Class : 1
# --------------------------------------------------
# 14 Text feature [hotspots] present in test data point [True]
# 19 Text feature [surface] present in test data point [True]
# 24 Text feature [hydrophobic] present in test data point [True]
# 75 Text feature [identify] present in test data point [True]
# 89 Text feature [strand] present in test data point [True]
# 100 Text feature [function] present in test data point [True]
# 108 Text feature [position] present in test data point [True]
# 122 Text feature [encoding] present in test data point [True]
# 124 Text feature [molecules] present in test data point [True]
# 133 Text feature [box] present in test data point [True]
# 141 Text feature [pa] present in test data point [True]
# 170 Text feature [region] present in test data point [True]
# 179 Text feature [loss] present in test data point [True]
# 209 Text feature [structure] present in test data point [True]
# 212 Text feature [possible] present in test data point [True]
# 213 Text feature [interact] present in test data point [True]
# 215 Text feature [analyses] present in test data point [True]
# 218 Text feature [specificity] present in test data point [True]
# 222 Text feature [complex] present in test data point [True]
# 234 Text feature [biological] present in test data point [True]
# 239 Text feature [population] present in test data point [True]
# 242 Text feature [interestingly] present in test data point [True]
# 249 Text feature [vivo] present in test data point [True]
# 254 Text feature [crystal] present in test data point [True]
# 258 Text feature [wild] present in test data point [True]
# 266 Text feature [nucleotide] present in test data point [True]
# 267 Text feature [calculated] present in test data point [True]
# 272 Text feature [sample] present in test data point [True]
# 274 Text feature [tagged] present in test data point [True]
# 275 Text feature [complexes] present in test data point [True]
# 289 Text feature [directed] present in test data point [True]
# 290 Text feature [mutagenesis] present in test data point [True]
# 291 Text feature [one] present in test data point [True]
# 299 Text feature [type] present in test data point [True]
# 300 Text feature [side] present in test data point [True]
# 308 Text feature [line] present in test data point [True]
# 311 Text feature [role] present in test data point [True]
# 324 Text feature [interactions] present in test data point [True]
# 330 Text feature [binding] present in test data point [True]
# 332 Text feature [30] present in test data point [True]
# 333 Text feature [dependent] present in test data point [True]
# 337 Text feature [located] present in test data point [True]
# 338 Text feature [100] present in test data point [True]
# 340 Text feature [hotspot] present in test data point [True]
# 346 Text feature [domains] present in test data point [True]
# 347 Text feature [therefore] present in test data point [True]
# 349 Text feature [residue] present in test data point [True]
# 350 Text feature [frequency] present in test data point [True]
# 351 Text feature [regulatory] present in test data point [True]
# 357 Text feature [sequencing] present in test data point [True]
# 358 Text feature [among] present in test data point [True]
# 364 Text feature [cell] present in test data point [True]
# 366 Text feature [previous] present in test data point [True]
# 367 Text feature [conditions] present in test data point [True]
# 371 Text feature [furthermore] present in test data point [True]
# 378 Text feature [least] present in test data point [True]
# 382 Text feature [1997] present in test data point [True]
# 385 Text feature [codon] present in test data point [True]
# 389 Text feature [large] present in test data point [True]
# 397 Text feature [peptide] present in test data point [True]
# 398 Text feature [within] present in test data point [True]
# 403 Text feature [added] present in test data point [True]
# 405 Text feature [containing] present in test data point [True]
# 407 Text feature [determined] present in test data point [True]
# 412 Text feature [table] present in test data point [True]
# 413 Text feature [fig] present in test data point [True]
# 414 Text feature [present] present in test data point [True]
# 416 Text feature [based] present in test data point [True]
# 422 Text feature [involved] present in test data point [True]
# 424 Text feature [proteins] present in test data point [True]
# 426 Text feature [significantly] present in test data point [True]
# 427 Text feature [dna] present in test data point [True]
# 429 Text feature [54] present in test data point [True]
# 433 Text feature [structures] present in test data point [True]
# 435 Text feature [reported] present in test data point [True]
# 437 Text feature [observed] present in test data point [True]
# 451 Text feature [2008] present in test data point [True]
# 455 Text feature [values] present in test data point [True]
# 457 Text feature [protein] present in test data point [True]
# 459 Text feature [mean] present in test data point [True]
# 460 Text feature [either] present in test data point [True]
# 467 Text feature [subunit] present in test data point [True]
# 472 Text feature [contains] present in test data point [True]
# 475 Text feature [reverse] present in test data point [True]
# 483 Text feature [25] present in test data point [True]
# 492 Text feature [structural] present in test data point [True]
# 493 Text feature [p53] present in test data point [True]
# 494 Text feature [major] present in test data point [True]
# 495 Text feature [59] present in test data point [True]
# 498 Text feature [appears] present in test data point [True]
# Out of the top  500  features  90 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[3.700e-03 2.229e-01 1.310e-02 9.000e-04 1.350e-02 2.880e-02 7.126e-01
#   4.000e-03 6.000e-04]]
# Actual Class : 2
# --------------------------------------------------
# 9 Text feature [overexpression] present in test data point [True]
# 12 Text feature [3b] present in test data point [True]
# 17 Text feature [enhanced] present in test data point [True]
# 18 Text feature [oncogene] present in test data point [True]
# 19 Text feature [activation] present in test data point [True]
# 26 Text feature [ligand] present in test data point [True]
# 30 Text feature [downstream] present in test data point [True]
# 40 Text feature [provided] present in test data point [True]
# 41 Text feature [observations] present in test data point [True]
# 42 Text feature [activated] present in test data point [True]
# 46 Text feature [constitutive] present in test data point [True]
# 49 Text feature [previously] present in test data point [True]
# 50 Text feature [transforming] present in test data point [True]
# 55 Text feature [specimens] present in test data point [True]
# 58 Text feature [transformed] present in test data point [True]
# 72 Text feature [advanced] present in test data point [True]
# 78 Text feature [activating] present in test data point [True]
# 80 Text feature [inhibited] present in test data point [True]
# 84 Text feature [2b] present in test data point [True]
# 86 Text feature [cancers] present in test data point [True]
# 87 Text feature [extracellular] present in test data point [True]
# 88 Text feature [membrane] present in test data point [True]
# 90 Text feature [ras] present in test data point [True]
# 92 Text feature [mechanisms] present in test data point [True]
# 94 Text feature [derived] present in test data point [True]
# 101 Text feature [standard] present in test data point [True]
# 104 Text feature [epithelial] present in test data point [True]
# 113 Text feature [examined] present in test data point [True]
# 119 Text feature [adenocarcinoma] present in test data point [True]
# 121 Text feature [size] present in test data point [True]
# 130 Text feature [inhibitor] present in test data point [True]
# 132 Text feature [akt] present in test data point [True]
# 134 Text feature [approximately] present in test data point [True]
# 141 Text feature [days] present in test data point [True]
# 143 Text feature [pathways] present in test data point [True]
# 144 Text feature [cdna] present in test data point [True]
# 162 Text feature [2a] present in test data point [True]
# 168 Text feature [concentrations] present in test data point [True]
# 173 Text feature [express] present in test data point [True]
# 175 Text feature [increase] present in test data point [True]
# 176 Text feature [factor] present in test data point [True]
# 178 Text feature [72] present in test data point [True]
# 188 Text feature [increased] present in test data point [True]
# 190 Text feature [blood] present in test data point [True]
# 193 Text feature [3a] present in test data point [True]
# 194 Text feature [colony] present in test data point [True]
# 197 Text feature [proliferation] present in test data point [True]
# 206 Text feature [promote] present in test data point [True]
# 207 Text feature [nsclc] present in test data point [True]
# 210 Text feature [leading] present in test data point [True]
# 213 Text feature [expressing] present in test data point [True]
# 214 Text feature [mutant] present in test data point [True]
# 215 Text feature [sites] present in test data point [True]
# 218 Text feature [genomic] present in test data point [True]
# 220 Text feature [signaling] present in test data point [True]
# 221 Text feature [leukemia] present in test data point [True]
# 222 Text feature [responses] present in test data point [True]
# 237 Text feature [versus] present in test data point [True]
# 238 Text feature [include] present in test data point [True]
# 240 Text feature [common] present in test data point [True]
# 242 Text feature [lung] present in test data point [True]
# 245 Text feature [carcinoma] present in test data point [True]
# 247 Text feature [position] present in test data point [True]
# 249 Text feature [myeloid] present in test data point [True]
# 251 Text feature [nm] present in test data point [True]
# 252 Text feature [tyrosine] present in test data point [True]
# 253 Text feature [biological] present in test data point [True]
# 255 Text feature [conditions] present in test data point [True]
# 256 Text feature [properties] present in test data point [True]
# 258 Text feature [egfr] present in test data point [True]
# 259 Text feature [form] present in test data point [True]
# 268 Text feature [stat3] present in test data point [True]
# 271 Text feature [survival] present in test data point [True]
# 277 Text feature [progression] present in test data point [True]
# 279 Text feature [3t3] present in test data point [True]
# 280 Text feature [demonstrated] present in test data point [True]
# 281 Text feature [culture] present in test data point [True]
# 282 Text feature [signals] present in test data point [True]
# 287 Text feature [driven] present in test data point [True]
# 289 Text feature [prior] present in test data point [True]
# 293 Text feature [frequent] present in test data point [True]
# 304 Text feature [factors] present in test data point [True]
# 306 Text feature [note] present in test data point [True]
# 309 Text feature [75] present in test data point [True]
# 311 Text feature [tissues] present in test data point [True]
# 320 Text feature [download] present in test data point [True]
# 324 Text feature [involving] present in test data point [True]
# 326 Text feature [bp] present in test data point [True]
# 327 Text feature [leads] present in test data point [True]
# 329 Text feature [gefitinib] present in test data point [True]
# 330 Text feature [harboring] present in test data point [True]
# 334 Text feature [sirna] present in test data point [True]
# 337 Text feature [high] present in test data point [True]
# 339 Text feature [positive] present in test data point [True]
# 345 Text feature [contribute] present in test data point [True]
# 346 Text feature [egf] present in test data point [True]
# 347 Text feature [stage] present in test data point [True]
# 354 Text feature [use] present in test data point [True]
# 358 Text feature [presence] present in test data point [True]
# 360 Text feature [61] present in test data point [True]
# 361 Text feature [brain] present in test data point [True]
# 366 Text feature [region] present in test data point [True]
# 368 Text feature [sensitive] present in test data point [True]
# 370 Text feature [addition] present in test data point [True]
# 383 Text feature [oncogenic] present in test data point [True]
# 389 Text feature [phosphorylation] present in test data point [True]
# 390 Text feature [transcription] present in test data point [True]
# 391 Text feature [absence] present in test data point [True]
# 394 Text feature [4a] present in test data point [True]
# 395 Text feature [comparison] present in test data point [True]
# 396 Text feature [example] present in test data point [True]
# 398 Text feature [upon] present in test data point [True]
# 399 Text feature [free] present in test data point [True]
# 400 Text feature [receptors] present in test data point [True]
# 408 Text feature [consistent] present in test data point [True]
# 409 Text feature [additional] present in test data point [True]
# 411 Text feature [49] present in test data point [True]
# 412 Text feature [suggest] present in test data point [True]
# 416 Text feature [greater] present in test data point [True]
# 418 Text feature [measured] present in test data point [True]
# 419 Text feature [together] present in test data point [True]
# 420 Text feature [distinct] present in test data point [True]
# 425 Text feature [51] present in test data point [True]
# 427 Text feature [52] present in test data point [True]
# 430 Text feature [mutants] present in test data point [True]
# 431 Text feature [kinases] present in test data point [True]
# 432 Text feature [regulated] present in test data point [True]
# 434 Text feature [mechanism] present in test data point [True]
# 439 Text feature [potent] present in test data point [True]
# 441 Text feature [prostate] present in test data point [True]
# 442 Text feature [cyclin] present in test data point [True]
# 445 Text feature [substitution] present in test data point [True]
# 448 Text feature [somatic] present in test data point [True]
# 453 Text feature [fold] present in test data point [True]
# 454 Text feature [introduction] present in test data point [True]
# 457 Text feature [14] present in test data point [True]
# 460 Text feature [interestingly] present in test data point [True]
# 464 Text feature [independent] present in test data point [True]
# 465 Text feature [furthermore] present in test data point [True]
# 468 Text feature [exon] present in test data point [True]
# 472 Text feature [dose] present in test data point [True]
# 473 Text feature [fusions] present in test data point [True]
# 474 Text feature [experiments] present in test data point [True]
# 477 Text feature [vector] present in test data point [True]
# 478 Text feature [either] present in test data point [True]
# 479 Text feature [figures] present in test data point [True]
# 484 Text feature [effective] present in test data point [True]
# 485 Text feature [fraction] present in test data point [True]
# 486 Text feature [lead] present in test data point [True]
# 488 Text feature [determine] present in test data point [True]
# 492 Text feature [nucleotide] present in test data point [True]
# 494 Text feature [total] present in test data point [True]
# 495 Text feature [found] present in test data point [True]
# 496 Text feature [subsequent] present in test data point [True]
# 497 Text feature [possibility] present in test data point [True]
# 499 Text feature [respectively] present in test data point [True]
# Out of the top  500  features  156 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %% [markdown]
# <h3>4.4.1. Hyper paramter tuning</h3>

# %%
alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.06385975778541
# for C = 0.0001
# Log Loss : 1.0288845349572442
# for C = 0.001
# Log Loss : 1.0444247027765483
# for C = 0.01
# Log Loss : 1.376117069378729
# for C = 0.1
# Log Loss : 1.693507063998967
# for C = 1
# Log Loss : 1.796519210051284
# for C = 10
# Log Loss : 1.7965191406687764
# for C = 100
# Log Loss : 1.796519188907789
# For values of best alpha =  0.0001 The train log loss is: 0.6783337649310044
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0288845349572442
# For values of best alpha =  0.0001 The test log loss is: 1.1072925425408062

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.0288845349572442
# Number of mis-classified points : 0.3383458646616541
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.4974 0.0524 0.005  0.1633 0.0333 0.1561 0.084  0.0061 0.0025]]
# Actual Class : 1
# --------------------------------------------------
# 48 Text feature [hydrophobic] present in test data point [True]
# 49 Text feature [hotspots] present in test data point [True]
# 50 Text feature [surface] present in test data point [True]
# 51 Text feature [position] present in test data point [True]
# 145 Text feature [encoding] present in test data point [True]
# 146 Text feature [identify] present in test data point [True]
# 147 Text feature [molecules] present in test data point [True]
# 152 Text feature [function] present in test data point [True]
# 153 Text feature [strand] present in test data point [True]
# 155 Text feature [loss] present in test data point [True]
# 160 Text feature [box] present in test data point [True]
# 162 Text feature [tagged] present in test data point [True]
# 168 Text feature [analyses] present in test data point [True]
# 172 Text feature [line] present in test data point [True]
# 174 Text feature [complexes] present in test data point [True]
# 176 Text feature [conditions] present in test data point [True]
# 177 Text feature [interestingly] present in test data point [True]
# 178 Text feature [biological] present in test data point [True]
# 180 Text feature [wild] present in test data point [True]
# 185 Text feature [possible] present in test data point [True]
# 189 Text feature [complex] present in test data point [True]
# 194 Text feature [interactions] present in test data point [True]
# 195 Text feature [mutagenesis] present in test data point [True]
# 196 Text feature [region] present in test data point [True]
# 198 Text feature [interact] present in test data point [True]
# 209 Text feature [structure] present in test data point [True]
# 217 Text feature [pa] present in test data point [True]
# 222 Text feature [vivo] present in test data point [True]
# 227 Text feature [determined] present in test data point [True]
# 229 Text feature [nucleotide] present in test data point [True]
# 230 Text feature [sample] present in test data point [True]
# 234 Text feature [type] present in test data point [True]
# 235 Text feature [within] present in test data point [True]
# 239 Text feature [role] present in test data point [True]
# 312 Text feature [codon] present in test data point [True]
# 321 Text feature [side] present in test data point [True]
# 326 Text feature [among] present in test data point [True]
# 329 Text feature [population] present in test data point [True]
# 331 Text feature [directed] present in test data point [True]
# 334 Text feature [crystal] present in test data point [True]
# 338 Text feature [located] present in test data point [True]
# 339 Text feature [values] present in test data point [True]
# 340 Text feature [frequency] present in test data point [True]
# 347 Text feature [one] present in test data point [True]
# 349 Text feature [30] present in test data point [True]
# 353 Text feature [regulatory] present in test data point [True]
# 358 Text feature [59] present in test data point [True]
# 363 Text feature [based] present in test data point [True]
# 376 Text feature [dependent] present in test data point [True]
# 379 Text feature [compared] present in test data point [True]
# 380 Text feature [cell] present in test data point [True]
# 385 Text feature [fig] present in test data point [True]
# 386 Text feature [large] present in test data point [True]
# 391 Text feature [54] present in test data point [True]
# 393 Text feature [specificity] present in test data point [True]
# 397 Text feature [calculated] present in test data point [True]
# 399 Text feature [1997] present in test data point [True]
# 401 Text feature [obtained] present in test data point [True]
# 402 Text feature [protein] present in test data point [True]
# 419 Text feature [reverse] present in test data point [True]
# 421 Text feature [residue] present in test data point [True]
# 422 Text feature [therefore] present in test data point [True]
# 423 Text feature [independent] present in test data point [True]
# 426 Text feature [25] present in test data point [True]
# 430 Text feature [structures] present in test data point [True]
# 435 Text feature [either] present in test data point [True]
# 436 Text feature [binding] present in test data point [True]
# 442 Text feature [indicated] present in test data point [True]
# 446 Text feature [table] present in test data point [True]
# 452 Text feature [s1] present in test data point [True]
# 453 Text feature [domains] present in test data point [True]
# 455 Text feature [significantly] present in test data point [True]
# 460 Text feature [observed] present in test data point [True]
# 463 Text feature [red] present in test data point [True]
# 464 Text feature [sequencing] present in test data point [True]
# 465 Text feature [least] present in test data point [True]
# 466 Text feature [previous] present in test data point [True]
# 468 Text feature [recently] present in test data point [True]
# 469 Text feature [five] present in test data point [True]
# 470 Text feature [peptide] present in test data point [True]
# 472 Text feature [mutation] present in test data point [True]
# 474 Text feature [secondary] present in test data point [True]
# 480 Text feature [impact] present in test data point [True]
# 482 Text feature [present] present in test data point [True]
# 484 Text feature [100] present in test data point [True]
# 485 Text feature [proteins] present in test data point [True]
# 486 Text feature [terminus] present in test data point [True]
# 489 Text feature [tumor] present in test data point [True]
# Out of the top  500  features  88 are present in query point

# %% [markdown]
# <h4>4.3.3.2. For Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0286 0.2886 0.0114 0.0023 0.0159 0.0286 0.6185 0.005  0.0011]]
# Actual Class : 2
# --------------------------------------------------
# 8 Text feature [overexpression] present in test data point [True]
# 38 Text feature [3b] present in test data point [True]
# 39 Text feature [oncogene] present in test data point [True]
# 40 Text feature [provided] present in test data point [True]
# 41 Text feature [standard] present in test data point [True]
# 43 Text feature [ligand] present in test data point [True]
# 45 Text feature [cancers] present in test data point [True]
# 47 Text feature [enhanced] present in test data point [True]
# 48 Text feature [downstream] present in test data point [True]
# 49 Text feature [previously] present in test data point [True]
# 52 Text feature [epithelial] present in test data point [True]
# 55 Text feature [72] present in test data point [True]
# 57 Text feature [specimens] present in test data point [True]
# 58 Text feature [2b] present in test data point [True]
# 60 Text feature [transforming] present in test data point [True]
# 61 Text feature [activation] present in test data point [True]
# 62 Text feature [derived] present in test data point [True]
# 65 Text feature [leading] present in test data point [True]
# 66 Text feature [ras] present in test data point [True]
# 67 Text feature [examined] present in test data point [True]
# 69 Text feature [activated] present in test data point [True]
# 71 Text feature [observations] present in test data point [True]
# 164 Text feature [membrane] present in test data point [True]
# 166 Text feature [2a] present in test data point [True]
# 167 Text feature [extracellular] present in test data point [True]
# 169 Text feature [increase] present in test data point [True]
# 170 Text feature [activating] present in test data point [True]
# 172 Text feature [position] present in test data point [True]
# 173 Text feature [inhibited] present in test data point [True]
# 174 Text feature [mechanisms] present in test data point [True]
# 175 Text feature [transformed] present in test data point [True]
# 176 Text feature [include] present in test data point [True]
# 177 Text feature [lung] present in test data point [True]
# 178 Text feature [carcinoma] present in test data point [True]
# 179 Text feature [adenocarcinoma] present in test data point [True]
# 181 Text feature [approximately] present in test data point [True]
# 182 Text feature [concentrations] present in test data point [True]
# 183 Text feature [pathways] present in test data point [True]
# 184 Text feature [advanced] present in test data point [True]
# 185 Text feature [expressing] present in test data point [True]
# 186 Text feature [driven] present in test data point [True]
# 189 Text feature [blood] present in test data point [True]
# 190 Text feature [sites] present in test data point [True]
# 191 Text feature [versus] present in test data point [True]
# 192 Text feature [increased] present in test data point [True]
# 193 Text feature [free] present in test data point [True]
# 194 Text feature [egfr] present in test data point [True]
# 197 Text feature [sirna] present in test data point [True]
# 198 Text feature [note] present in test data point [True]
# 199 Text feature [biological] present in test data point [True]
# 201 Text feature [factor] present in test data point [True]
# 202 Text feature [leukemia] present in test data point [True]
# 203 Text feature [akt] present in test data point [True]
# 205 Text feature [myeloid] present in test data point [True]
# 206 Text feature [conditions] present in test data point [True]
# 209 Text feature [introduction] present in test data point [True]
# 210 Text feature [size] present in test data point [True]
# 212 Text feature [express] present in test data point [True]
# 213 Text feature [common] present in test data point [True]
# 215 Text feature [high] present in test data point [True]
# 216 Text feature [cdna] present in test data point [True]
# 218 Text feature [signals] present in test data point [True]
# 220 Text feature [prior] present in test data point [True]
# 223 Text feature [leads] present in test data point [True]
# 227 Text feature [days] present in test data point [True]
# 228 Text feature [determine] present in test data point [True]
# 229 Text feature [responses] present in test data point [True]
# 230 Text feature [constitutive] present in test data point [True]
# 231 Text feature [additional] present in test data point [True]
# 234 Text feature [49] present in test data point [True]
# 237 Text feature [promote] present in test data point [True]
# 238 Text feature [mutant] present in test data point [True]
# 240 Text feature [form] present in test data point [True]
# 242 Text feature [properties] present in test data point [True]
# 243 Text feature [genomic] present in test data point [True]
# 244 Text feature [colony] present in test data point [True]
# 245 Text feature [proliferation] present in test data point [True]
# 246 Text feature [positive] present in test data point [True]
# 249 Text feature [sensitive] present in test data point [True]
# 251 Text feature [inhibitor] present in test data point [True]
# 252 Text feature [75] present in test data point [True]
# 255 Text feature [bp] present in test data point [True]
# 256 Text feature [comparison] present in test data point [True]
# 259 Text feature [region] present in test data point [True]
# 260 Text feature [survival] present in test data point [True]
# 261 Text feature [nsclc] present in test data point [True]
# 263 Text feature [4a] present in test data point [True]
# 264 Text feature [experiments] present in test data point [True]
# 265 Text feature [3a] present in test data point [True]
# 266 Text feature [upon] present in test data point [True]
# 269 Text feature [nm] present in test data point [True]
# 271 Text feature [download] present in test data point [True]
# 272 Text feature [involving] present in test data point [True]
# 273 Text feature [tyrosine] present in test data point [True]
# 275 Text feature [breast] present in test data point [True]
# 276 Text feature [motif] present in test data point [True]
# 278 Text feature [distinct] present in test data point [True]
# 280 Text feature [together] present in test data point [True]
# 281 Text feature [mechanism] present in test data point [True]
# 282 Text feature [progression] present in test data point [True]
# 284 Text feature [frequent] present in test data point [True]
# 288 Text feature [demonstrated] present in test data point [True]
# 289 Text feature [would] present in test data point [True]
# 290 Text feature [vector] present in test data point [True]
# 293 Text feature [61] present in test data point [True]
# 294 Text feature [either] present in test data point [True]
# 295 Text feature [stat3] present in test data point [True]
# 297 Text feature [example] present in test data point [True]
# 298 Text feature [regulated] present in test data point [True]
# 299 Text feature [prostate] present in test data point [True]
# 300 Text feature [initial] present in test data point [True]
# 301 Text feature [figures] present in test data point [True]
# 302 Text feature [gefitinib] present in test data point [True]
# 303 Text feature [harboring] present in test data point [True]
# 304 Text feature [regions] present in test data point [True]
# 305 Text feature [measured] present in test data point [True]
# 306 Text feature [stage] present in test data point [True]
# 438 Text feature [deletion] present in test data point [True]
# 439 Text feature [disease] present in test data point [True]
# 440 Text feature [recurrent] present in test data point [True]
# 441 Text feature [substitution] present in test data point [True]
# 442 Text feature [factors] present in test data point [True]
# 444 Text feature [published] present in test data point [True]
# 445 Text feature [20] present in test data point [True]
# 446 Text feature [mutants] present in test data point [True]
# 447 Text feature [signaling] present in test data point [True]
# 448 Text feature [addition] present in test data point [True]
# 450 Text feature [phosphorylation] present in test data point [True]
# 451 Text feature [suggest] present in test data point [True]
# 452 Text feature [available] present in test data point [True]
# 454 Text feature [see] present in test data point [True]
# 455 Text feature [respectively] present in test data point [True]
# 456 Text feature [52] present in test data point [True]
# 457 Text feature [transcription] present in test data point [True]
# 458 Text feature [lead] present in test data point [True]
# 460 Text feature [tissues] present in test data point [True]
# 462 Text feature [greater] present in test data point [True]
# 465 Text feature [independent] present in test data point [True]
# 467 Text feature [37] present in test data point [True]
# 469 Text feature [culture] present in test data point [True]
# 476 Text feature [50] present in test data point [True]
# 477 Text feature [total] present in test data point [True]
# 478 Text feature [exon] present in test data point [True]
# 479 Text feature [use] present in test data point [True]
# 480 Text feature [hours] present in test data point [True]
# 481 Text feature [structure] present in test data point [True]
# 482 Text feature [egf] present in test data point [True]
# 488 Text feature [brain] present in test data point [True]
# 489 Text feature [furthermore] present in test data point [True]
# 490 Text feature [dose] present in test data point [True]
# 491 Text feature [contains] present in test data point [True]
# 492 Text feature [product] present in test data point [True]
# 494 Text feature [consistent] present in test data point [True]
# 496 Text feature [showed] present in test data point [True]
# 497 Text feature [cells] present in test data point [True]
# 498 Text feature [ii] present in test data point [True]
# 499 Text feature [pi3k] present in test data point [True]
# Out of the top  500  features  157 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With One hot Encoding)</h3>

# %%
alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_onehotCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.1668805475203725
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.2267289811424544
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.1571043226817501
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.209588308752844
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.1449050203982865
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.2026785955417718
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.1489076711900816
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.1996580915591748
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.1460788818304761
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.1988251759941426
# For values of best estimator =  500 The train log loss is: 0.8462426840042052
# For values of best estimator =  500 The cross validation log loss is: 1.1449050203982865
# For values of best estimator =  500 The test log loss is: 1.2312880686783536

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.1449050203982865
# Number of mis-classified points : 0.41353383458646614
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.3462 0.0237 0.0116 0.4354 0.056  0.0783 0.0305 0.0046 0.0135]]
# Actual Class : 1
# --------------------------------------------------
# 5 Text feature [function] present in test data point [True]
# 6 Text feature [activation] present in test data point [True]
# 8 Text feature [suppressor] present in test data point [True]
# 9 Text feature [loss] present in test data point [True]
# 11 Text feature [missense] present in test data point [True]
# 18 Text feature [protein] present in test data point [True]
# 19 Text feature [functional] present in test data point [True]
# 27 Text feature [stability] present in test data point [True]
# 36 Text feature [cells] present in test data point [True]
# 40 Text feature [oncogenic] present in test data point [True]
# 46 Text feature [expression] present in test data point [True]
# 52 Text feature [cell] present in test data point [True]
# 53 Text feature [activity] present in test data point [True]
# 59 Text feature [downstream] present in test data point [True]
# 70 Text feature [response] present in test data point [True]
# 72 Text feature [tagged] present in test data point [True]
# 74 Text feature [proteins] present in test data point [True]
# 78 Text feature [dna] present in test data point [True]
# 93 Text feature [57] present in test data point [True]
# Out of the top  100  features  19 are present in query point

# %% [markdown]
# <h4>4.5.3.2. Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.012  0.2467 0.0154 0.012  0.0316 0.0245 0.6524 0.0042 0.0013]]
# Actuall Class : 2
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 1 Text feature [activating] present in test data point [True]
# 2 Text feature [activated] present in test data point [True]
# 3 Text feature [phosphorylation] present in test data point [True]
# 4 Text feature [tyrosine] present in test data point [True]
# 5 Text feature [function] present in test data point [True]
# 6 Text feature [activation] present in test data point [True]
# 7 Text feature [inhibitors] present in test data point [True]
# 8 Text feature [suppressor] present in test data point [True]
# 9 Text feature [loss] present in test data point [True]
# 10 Text feature [constitutive] present in test data point [True]
# 11 Text feature [missense] present in test data point [True]
# 12 Text feature [inhibitor] present in test data point [True]
# 13 Text feature [treatment] present in test data point [True]
# 16 Text feature [constitutively] present in test data point [True]
# 18 Text feature [protein] present in test data point [True]
# 19 Text feature [functional] present in test data point [True]
# 21 Text feature [erk] present in test data point [True]
# 22 Text feature [transforming] present in test data point [True]
# 23 Text feature [trials] present in test data point [True]
# 25 Text feature [therapeutic] present in test data point [True]
# 26 Text feature [variants] present in test data point [True]
# 29 Text feature [phosphatase] present in test data point [True]
# 30 Text feature [growth] present in test data point [True]
# 31 Text feature [ba] present in test data point [True]
# 36 Text feature [cells] present in test data point [True]
# 38 Text feature [ring] present in test data point [True]
# 39 Text feature [kinases] present in test data point [True]
# 40 Text feature [oncogenic] present in test data point [True]
# 41 Text feature [receptor] present in test data point [True]
# 42 Text feature [efficacy] present in test data point [True]
# 44 Text feature [therapy] present in test data point [True]
# 45 Text feature [extracellular] present in test data point [True]
# 46 Text feature [expression] present in test data point [True]
# 47 Text feature [drug] present in test data point [True]
# 49 Text feature [ic50] present in test data point [True]
# 51 Text feature [nsclc] present in test data point [True]
# 52 Text feature [cell] present in test data point [True]
# 53 Text feature [activity] present in test data point [True]
# 55 Text feature [inhibition] present in test data point [True]
# 56 Text feature [inactivation] present in test data point [True]
# 57 Text feature [functions] present in test data point [True]
# 58 Text feature [survival] present in test data point [True]
# 59 Text feature [downstream] present in test data point [True]
# 60 Text feature [sensitivity] present in test data point [True]
# 61 Text feature [f3] present in test data point [True]
# 62 Text feature [patients] present in test data point [True]
# 63 Text feature [lines] present in test data point [True]
# 64 Text feature [months] present in test data point [True]
# 65 Text feature [inhibited] present in test data point [True]
# 67 Text feature [akt] present in test data point [True]
# 68 Text feature [assays] present in test data point [True]
# 70 Text feature [response] present in test data point [True]
# 71 Text feature [expressing] present in test data point [True]
# 73 Text feature [signaling] present in test data point [True]
# 74 Text feature [proteins] present in test data point [True]
# 75 Text feature [proliferation] present in test data point [True]
# 76 Text feature [mammalian] present in test data point [True]
# 77 Text feature [clinical] present in test data point [True]
# 79 Text feature [harboring] present in test data point [True]
# 80 Text feature [imatinib] present in test data point [True]
# 81 Text feature [egfr] present in test data point [True]
# 82 Text feature [treated] present in test data point [True]
# 85 Text feature [ras] present in test data point [True]
# 86 Text feature [advanced] present in test data point [True]
# 87 Text feature [variant] present in test data point [True]
# 90 Text feature [potential] present in test data point [True]
# 91 Text feature [use] present in test data point [True]
# 92 Text feature [resistance] present in test data point [True]
# 93 Text feature [57] present in test data point [True]
# 94 Text feature [transformation] present in test data point [True]
# 96 Text feature [history] present in test data point [True]
# 97 Text feature [combined] present in test data point [True]
# 99 Text feature [3t3] present in test data point [True]
# Out of the top  100  features  74 are present in query point

# %% [markdown]
# <h3>4.5.3. Hyper paramter tuning (With Response Coding)</h3>

# %%
alpha = [10,50,100,200,500,1000]
max_depth = [2,3,5,10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_responseCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_responseCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 10 and max depth =  2
# Log Loss : 2.1254016645675997
# for n_estimators = 10 and max depth =  3
# Log Loss : 1.6856124289799996
# for n_estimators = 10 and max depth =  5
# Log Loss : 1.4133044352811732
# for n_estimators = 10 and max depth =  10
# Log Loss : 1.9509569753230975
# for n_estimators = 50 and max depth =  2
# Log Loss : 1.7278000102519553
# for n_estimators = 50 and max depth =  3
# Log Loss : 1.447206722603623
# for n_estimators = 50 and max depth =  5
# Log Loss : 1.3753119953285222
# for n_estimators = 50 and max depth =  10
# Log Loss : 1.6497916738396905
# for n_estimators = 100 and max depth =  2
# Log Loss : 1.5958668614905098
# for n_estimators = 100 and max depth =  3
# Log Loss : 1.4812038146396662
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.3193081399080804
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.7012613657387357
# for n_estimators = 200 and max depth =  2
# Log Loss : 1.655651063714378
# for n_estimators = 200 and max depth =  3
# Log Loss : 1.4836181470082848
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.3382424409159737
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.718406953573972
# for n_estimators = 500 and max depth =  2
# Log Loss : 1.6681968020920617
# for n_estimators = 500 and max depth =  3
# Log Loss : 1.5393202495083522
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.3856617731666017
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.8003849635343203
# for n_estimators = 1000 and max depth =  2
# Log Loss : 1.6475538717511589
# for n_estimators = 1000 and max depth =  3
# Log Loss : 1.5400141797058007
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.3805944063683089
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.8022984105224356
# For values of best alpha =  100 The train log loss is: 0.060468888530703806
# For values of best alpha =  100 The cross validation log loss is: 1.3193081399080804
# For values of best alpha =  100 The test log loss is: 1.3556108986121227

# %% [markdown]
# <h3>4.5.4. Testing model with best hyper parameters (Response Coding)</h3>

# %%
clf = RandomForestClassifier(max_depth=max_depth[int(best_alpha%4)], n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_features='auto',random_state=42)
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y,cv_x_responseCoding,cv_y, clf)
# Out:
# Log loss : 1.3193081399080806
# Number of mis-classified points : 0.4718045112781955
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.5. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.5.1. Correctly Classified point</h4>

# %%
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)


test_point_index = 1
no_feature = 27
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.343  0.0242 0.151  0.2762 0.051  0.0947 0.0107 0.0225 0.0268]]
# Actual Class : 1
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Variation is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h4>4.5.5.2. Incorrectly Classified point</h4>

# %%
test_point_index = 100
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0015 0.3102 0.0017 0.0035 0.0008 0.0068 0.6718 0.0018 0.0018]]
# Actual Class : 2
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Variation is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=1, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=0.001)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 1.00
# Support vector machines : Log Loss: 1.80
# Naive Bayes : Log Loss: 1.14
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.178
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 2.035
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.502
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.102
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.090
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.156

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.8099667986879918
# Log loss (CV) on the stacking classifier : 1.1021321304446055
# Log loss (test) on the stacking classifier : 1.1890366594262638
# Number of missclassified point : 0.4030075187969925
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.7.3 Maximum Voting classifier </h3>

# %%
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the VotingClassifier : 0.9501577797532984
# Log loss (CV) on the VotingClassifier : 1.1585194678967439
# Log loss (test) on the VotingClassifier : 1.2259413302146585
# Number of missclassified point : 0.3954887218045113
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # Logistic regression with CountVectorizer Features, including unigrams , bigrams and ngram

# %% [markdown]
# # Tokenising

# %%
#Count Vectorizer for Gene feature on 1000 top features
gene_vectorizer = CountVectorizer(ngram_range=(1, 1),max_features=1000)
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
#Count Vectorizer for Variation feature on 1000 top features
Variation_vectorizer = CountVectorizer(ngram_range=(1, 1),max_features=1000)
train_variation_feature_onehotCoding = Variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = Variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = Variation_vectorizer.transform(cv_df['Variation'])

# %%
Text_vectorizer = CountVectorizer(ngram_range=(1, 1),max_features=1000)
train_text_feature_onehotCoding = Text_vectorizer.fit_transform(train_df['TEXT'])
test_text_feature_onehotCoding = Text_vectorizer.transform(test_df['TEXT'])
cv_text_feature_onehotCoding = Text_vectorizer.transform(cv_df['TEXT'])

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
#test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
#cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))

# %% [markdown]
# # Hyper parameter tuning

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1983330576756601
# for alpha = 1e-05
# Log Loss : 1.149287767178269
# for alpha = 0.0001
# Log Loss : 1.0513491568469642
# for alpha = 0.001
# Log Loss : 1.1365373599245403
# for alpha = 0.01
# Log Loss : 1.3687946366899477
# for alpha = 0.1
# Log Loss : 1.7448118651301205
# for alpha = 1
# Log Loss : 1.7825957530551004
# for alpha = 10
# Log Loss : 1.7867474771210665
# for alpha = 100
# Log Loss : 1.7872443433427043
# For values of best alpha =  0.0001 The train log loss is: 0.6026432915506269
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0513491568469642
# For values of best alpha =  0.0001 The test log loss is: 0.9990609624440077

# %% [markdown]
# # Testing the model with best hyper parameters

# %%
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0513491568469642
# Number of mis-classified points : 0.3458646616541353
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # Correctly Classified point

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.1164 0.0513 0.262  0.4091 0.0808 0.0214 0.0434 0.0081 0.0074]]
# Actual Class : 4
# --------------------------------------------------
# 28 Text feature [mammalian] present in test data point [True]
# 49 Text feature [missense] present in test data point [True]
# 60 Text feature [washed] present in test data point [True]
# 70 Text feature [assay] present in test data point [True]
# 98 Text feature [iii] present in test data point [True]
# 105 Text feature [functional] present in test data point [True]
# 114 Text feature [show] present in test data point [True]
# 119 Text feature [phenotype] present in test data point [True]
# 188 Text feature [transfection] present in test data point [True]
# 193 Text feature [therefore] present in test data point [True]
# 194 Text feature [tested] present in test data point [True]
# 202 Text feature [resulting] present in test data point [True]
# 214 Text feature [mm] present in test data point [True]
# 217 Text feature [tagged] present in test data point [True]
# 221 Text feature [mutants] present in test data point [True]
# 226 Text feature [assays] present in test data point [True]
# 228 Text feature [free] present in test data point [True]
# 232 Text feature [tumours] present in test data point [True]
# 237 Text feature [function] present in test data point [True]
# 250 Text feature [neutral] present in test data point [True]
# 257 Text feature [mouse] present in test data point [True]
# 265 Text feature [ca] present in test data point [True]
# 270 Text feature [comparison] present in test data point [True]
# 279 Text feature [age] present in test data point [True]
# 281 Text feature [changes] present in test data point [True]
# 283 Text feature [protein] present in test data point [True]
# 286 Text feature [results] present in test data point [True]
# 289 Text feature [investigated] present in test data point [True]
# 291 Text feature [families] present in test data point [True]
# 294 Text feature [approximately] present in test data point [True]
# 302 Text feature [buffer] present in test data point [True]
# 307 Text feature [see] present in test data point [True]
# 311 Text feature [caused] present in test data point [True]
# 314 Text feature [indicate] present in test data point [True]
# 315 Text feature [unable] present in test data point [True]
# 316 Text feature [differences] present in test data point [True]
# 319 Text feature [despite] present in test data point [True]
# 321 Text feature [29] present in test data point [True]
# 336 Text feature [determine] present in test data point [True]
# 340 Text feature [3b] present in test data point [True]
# 341 Text feature [proportion] present in test data point [True]
# 342 Text feature [genetic] present in test data point [True]
# 345 Text feature [manufacturer] present in test data point [True]
# 346 Text feature [antibody] present in test data point [True]
# 349 Text feature [materials] present in test data point [True]
# 353 Text feature [2a] present in test data point [True]
# 358 Text feature [transfected] present in test data point [True]
# 362 Text feature [family] present in test data point [True]
# 364 Text feature [heterozygous] present in test data point [True]
# 367 Text feature [indicating] present in test data point [True]
# 377 Text feature [suggesting] present in test data point [True]
# 379 Text feature [pa] present in test data point [True]
# 381 Text feature [change] present in test data point [True]
# 386 Text feature [activity] present in test data point [True]
# 387 Text feature [several] present in test data point [True]
# 391 Text feature [due] present in test data point [True]
# 400 Text feature [methods] present in test data point [True]
# 404 Text feature [times] present in test data point [True]
# 407 Text feature [effect] present in test data point [True]
# 409 Text feature [presented] present in test data point [True]
# 410 Text feature [30] present in test data point [True]
# 411 Text feature [constructs] present in test data point [True]
# 414 Text feature [predicted] present in test data point [True]
# 417 Text feature [contribute] present in test data point [True]
# 421 Text feature [variants] present in test data point [True]
# 423 Text feature [locus] present in test data point [True]
# 429 Text feature [large] present in test data point [True]
# 431 Text feature [low] present in test data point [True]
# 434 Text feature [since] present in test data point [True]
# 437 Text feature [next] present in test data point [True]
# 438 Text feature [vector] present in test data point [True]
# 445 Text feature [similarly] present in test data point [True]
# 446 Text feature [min] present in test data point [True]
# 449 Text feature [terminal] present in test data point [True]
# 450 Text feature [frequently] present in test data point [True]
# 451 Text feature [2b] present in test data point [True]
# 452 Text feature [contains] present in test data point [True]
# 453 Text feature [following] present in test data point [True]
# 456 Text feature [likely] present in test data point [True]
# 467 Text feature [individuals] present in test data point [True]
# 470 Text feature [levels] present in test data point [True]
# 471 Text feature [eight] present in test data point [True]
# 478 Text feature [16] present in test data point [True]
# 480 Text feature [affected] present in test data point [True]
# 482 Text feature [dna] present in test data point [True]
# 484 Text feature [whether] present in test data point [True]
# 488 Text feature [deletion] present in test data point [True]
# 490 Text feature [variant] present in test data point [True]
# 494 Text feature [splicing] present in test data point [True]
# 495 Text feature [37] present in test data point [True]
# 499 Text feature [dominant] present in test data point [True]
# Out of the top  500  features  91 are present in query point

# %% [markdown]
# # Incorrectly Classified point

# %%
test_point_index = 50
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0058 0.2715 0.0011 0.004  0.0232 0.0193 0.6719 0.0019 0.0012]]
# Actual Class : 2
# --------------------------------------------------
# 12 Text feature [extracellular] present in test data point [True]
# 17 Text feature [downstream] present in test data point [True]
# 18 Text feature [constitutive] present in test data point [True]
# 25 Text feature [transformed] present in test data point [True]
# 36 Text feature [constitutively] present in test data point [True]
# 42 Text feature [expressing] present in test data point [True]
# 50 Text feature [concentrations] present in test data point [True]
# 60 Text feature [carcinomas] present in test data point [True]
# 63 Text feature [approximately] present in test data point [True]
# 70 Text feature [3b] present in test data point [True]
# 73 Text feature [inhibitor] present in test data point [True]
# 85 Text feature [s3] present in test data point [True]
# 89 Text feature [adenocarcinoma] present in test data point [True]
# 93 Text feature [cancers] present in test data point [True]
# 111 Text feature [driven] present in test data point [True]
# 119 Text feature [derived] present in test data point [True]
# 132 Text feature [lung] present in test data point [True]
# 136 Text feature [lead] present in test data point [True]
# 138 Text feature [overexpression] present in test data point [True]
# 141 Text feature [carcinoma] present in test data point [True]
# 147 Text feature [ligand] present in test data point [True]
# 155 Text feature [high] present in test data point [True]
# 160 Text feature [day] present in test data point [True]
# 164 Text feature [activated] present in test data point [True]
# 165 Text feature [2b] present in test data point [True]
# 174 Text feature [sensitive] present in test data point [True]
# 187 Text feature [3a] present in test data point [True]
# 191 Text feature [observations] present in test data point [True]
# 207 Text feature [various] present in test data point [True]
# 210 Text feature [elevated] present in test data point [True]
# 211 Text feature [presence] present in test data point [True]
# 212 Text feature [enhanced] present in test data point [True]
# 217 Text feature [tyrosine] present in test data point [True]
# 222 Text feature [somatic] present in test data point [True]
# 226 Text feature [caused] present in test data point [True]
# 229 Text feature [coding] present in test data point [True]
# 233 Text feature [pathways] present in test data point [True]
# 238 Text feature [nm] present in test data point [True]
# 247 Text feature [per] present in test data point [True]
# 248 Text feature [serum] present in test data point [True]
# 252 Text feature [interestingly] present in test data point [True]
# 254 Text feature [common] present in test data point [True]
# 258 Text feature [sensitivity] present in test data point [True]
# 259 Text feature [positive] present in test data point [True]
# 260 Text feature [dose] present in test data point [True]
# 261 Text feature [1a] present in test data point [True]
# 262 Text feature [leading] present in test data point [True]
# 264 Text feature [added] present in test data point [True]
# 265 Text feature [tumorigenesis] present in test data point [True]
# 269 Text feature [recurrent] present in test data point [True]
# 271 Text feature [advanced] present in test data point [True]
# 272 Text feature [obtained] present in test data point [True]
# 274 Text feature [prostate] present in test data point [True]
# 275 Text feature [oncogenic] present in test data point [True]
# 284 Text feature [2a] present in test data point [True]
# 287 Text feature [occur] present in test data point [True]
# 289 Text feature [initial] present in test data point [True]
# 290 Text feature [therapy] present in test data point [True]
# 292 Text feature [fact] present in test data point [True]
# 293 Text feature [examined] present in test data point [True]
# 296 Text feature [substitution] present in test data point [True]
# 299 Text feature [specimens] present in test data point [True]
# 300 Text feature [inhibited] present in test data point [True]
# 302 Text feature [fold] present in test data point [True]
# 303 Text feature [basal] present in test data point [True]
# 306 Text feature [mutant] present in test data point [True]
# 308 Text feature [distinct] present in test data point [True]
# 310 Text feature [nucleotide] present in test data point [True]
# 316 Text feature [current] present in test data point [True]
# 320 Text feature [regulated] present in test data point [True]
# 328 Text feature [early] present in test data point [True]
# 335 Text feature [effective] present in test data point [True]
# 345 Text feature [treated] present in test data point [True]
# 347 Text feature [molecule] present in test data point [True]
# 349 Text feature [promote] present in test data point [True]
# 354 Text feature [egfr] present in test data point [True]
# 355 Text feature [50] present in test data point [True]
# 356 Text feature [mechanisms] present in test data point [True]
# 358 Text feature [see] present in test data point [True]
# 360 Text feature [sequenced] present in test data point [True]
# 361 Text feature [growth] present in test data point [True]
# 362 Text feature [position] present in test data point [True]
# 364 Text feature [difference] present in test data point [True]
# 370 Text feature [university] present in test data point [True]
# 371 Text feature [image] present in test data point [True]
# 374 Text feature [provided] present in test data point [True]
# 375 Text feature [absence] present in test data point [True]
# 386 Text feature [higher] present in test data point [True]
# 389 Text feature [size] present in test data point [True]
# 390 Text feature [bp] present in test data point [True]
# 392 Text feature [vector] present in test data point [True]
# 393 Text feature [seen] present in test data point [True]
# 394 Text feature [supplemental] present in test data point [True]
# 398 Text feature [medium] present in test data point [True]
# 400 Text feature [without] present in test data point [True]
# 401 Text feature [rates] present in test data point [True]
# 404 Text feature [found] present in test data point [True]
# 405 Text feature [properties] present in test data point [True]
# 406 Text feature [responses] present in test data point [True]
# 407 Text feature [conditions] present in test data point [True]
# 412 Text feature [wt] present in test data point [True]
# 413 Text feature [activating] present in test data point [True]
# 414 Text feature [confer] present in test data point [True]
# 417 Text feature [increased] present in test data point [True]
# 420 Text feature [gefitinib] present in test data point [True]
# 421 Text feature [figures] present in test data point [True]
# 424 Text feature [showed] present in test data point [True]
# 426 Text feature [total] present in test data point [True]
# 428 Text feature [previously] present in test data point [True]
# 430 Text feature [ng] present in test data point [True]
# 434 Text feature [activation] present in test data point [True]
# 436 Text feature [blood] present in test data point [True]
# 446 Text feature [regions] present in test data point [True]
# 449 Text feature [24] present in test data point [True]
# 451 Text feature [frequent] present in test data point [True]
# 453 Text feature [increase] present in test data point [True]
# 455 Text feature [characteristics] present in test data point [True]
# 459 Text feature [25] present in test data point [True]
# 460 Text feature [note] present in test data point [True]
# 462 Text feature [state] present in test data point [True]
# 463 Text feature [measured] present in test data point [True]
# 464 Text feature [gfp] present in test data point [True]
# 468 Text feature [resistant] present in test data point [True]
# 469 Text feature [52] present in test data point [True]
# 472 Text feature [selected] present in test data point [True]
# 473 Text feature [29] present in test data point [True]
# 479 Text feature [four] present in test data point [True]
# 481 Text feature [compared] present in test data point [True]
# 488 Text feature [less] present in test data point [True]
# 490 Text feature [18] present in test data point [True]
# 491 Text feature [mutants] present in test data point [True]
# 494 Text feature [proliferation] present in test data point [True]
# 496 Text feature [association] present in test data point [True]
# 497 Text feature [might] present in test data point [True]
# 499 Text feature [determined] present in test data point [True]
# Out of the top  500  features  135 are present in query point

# %% [markdown]
# # Tokenisation using Bow with max features = 1000

# %%
#Count Vectorizer for Gene feature on 1000 top features
gene_vectorizer = CountVectorizer(ngram_range=(1, 2),max_features=1000)
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
#Count Vectorizer for Variation feature on 1000 top features
Variation_vectorizer = CountVectorizer(ngram_range=(1, 2),max_features=1000)
train_variation_feature_onehotCoding = Variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = Variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = Variation_vectorizer.transform(cv_df['Variation'])

# %%
Text_vectorizer = CountVectorizer(ngram_range=(1, 2),max_features=1000)
train_text_feature_onehotCoding = Text_vectorizer.fit_transform(train_df['TEXT'])
test_text_feature_onehotCoding = Text_vectorizer.transform(test_df['TEXT'])
cv_text_feature_onehotCoding = Text_vectorizer.transform(cv_df['TEXT'])

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
#test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
#cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))

# %% [markdown]
# # Hyper parameter tuning

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.196957079513447
# for alpha = 1e-05
# Log Loss : 1.131428593591256
# for alpha = 0.0001
# Log Loss : 1.0455533835062545
# for alpha = 0.001
# Log Loss : 1.135920621816104
# for alpha = 0.01
# Log Loss : 1.3631292694643908
# for alpha = 0.1
# Log Loss : 1.739020246441431
# for alpha = 1
# Log Loss : 1.7785716888272576
# for alpha = 10
# Log Loss : 1.7829184367036375
# for alpha = 100
# Log Loss : 1.7834387131297502
# For values of best alpha =  0.0001 The train log loss is: 0.6099065740711911
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0455533835062545
# For values of best alpha =  0.0001 The test log loss is: 1.0059704547799062

# %% [markdown]
# # Testing the model with best hyper parameters

# %%
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0455533835062545
# Number of mis-classified points : 0.3458646616541353
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # Correctly Classified point

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.1097 0.0533 0.2607 0.4141 0.0793 0.0223 0.045  0.0082 0.0076]]
# Actual Class : 4
# --------------------------------------------------
# 52 Text feature [months] present in test data point [True]
# 63 Text feature [dependent] present in test data point [True]
# 105 Text feature [shown] present in test data point [True]
# 148 Text feature [deletion] present in test data point [True]
# 169 Text feature [transfected] present in test data point [True]
# 185 Text feature [two] present in test data point [True]
# 194 Text feature [added] present in test data point [True]
# 199 Text feature [downstream] present in test data point [True]
# 205 Text feature [table] present in test data point [True]
# 206 Text feature [locus] present in test data point [True]
# 207 Text feature [majority] present in test data point [True]
# 212 Text feature [kit] present in test data point [True]
# 217 Text feature [neutral] present in test data point [True]
# 218 Text feature [reduction] present in test data point [True]
# 223 Text feature [domain] present in test data point [True]
# 226 Text feature [mutations] present in test data point [True]
# 231 Text feature [pa] present in test data point [True]
# 233 Text feature [derived] present in test data point [True]
# 235 Text feature [compared] present in test data point [True]
# 236 Text feature [functional] present in test data point [True]
# 252 Text feature [furthermore] present in test data point [True]
# 255 Text feature [figure] present in test data point [True]
# 261 Text feature [cancer] present in test data point [True]
# 262 Text feature [tumours] present in test data point [True]
# 266 Text feature [confirmed] present in test data point [True]
# 268 Text feature [including] present in test data point [True]
# 272 Text feature [complexes] present in test data point [True]
# 279 Text feature [calculated] present in test data point [True]
# 284 Text feature [could] present in test data point [True]
# 290 Text feature [clinical] present in test data point [True]
# 293 Text feature [caused] present in test data point [True]
# 299 Text feature [similarly] present in test data point [True]
# 304 Text feature [enhanced] present in test data point [True]
# 306 Text feature [directly] present in test data point [True]
# 309 Text feature [role] present in test data point [True]
# 311 Text feature [hours] present in test data point [True]
# 313 Text feature [development] present in test data point [True]
# 320 Text feature [3a] present in test data point [True]
# 323 Text feature [differences] present in test data point [True]
# 324 Text feature [another] present in test data point [True]
# 327 Text feature [mechanisms] present in test data point [True]
# 331 Text feature [29] present in test data point [True]
# 332 Text feature [missense] present in test data point [True]
# 334 Text feature [blood] present in test data point [True]
# 339 Text feature [well] present in test data point [True]
# 342 Text feature [analysis] present in test data point [True]
# 349 Text feature [cell] present in test data point [True]
# 350 Text feature [products] present in test data point [True]
# 352 Text feature [unable] present in test data point [True]
# 357 Text feature [28] present in test data point [True]
# 358 Text feature [go] present in test data point [True]
# 363 Text feature [therefore] present in test data point [True]
# 369 Text feature [identified] present in test data point [True]
# 371 Text feature [individual] present in test data point [True]
# 372 Text feature [effects] present in test data point [True]
# 378 Text feature [inhibit] present in test data point [True]
# 390 Text feature [inhibitors] present in test data point [True]
# 398 Text feature [made] present in test data point [True]
# 400 Text feature [showing] present in test data point [True]
# 403 Text feature [levels] present in test data point [True]
# 405 Text feature [corresponding] present in test data point [True]
# 406 Text feature [associated] present in test data point [True]
# 408 Text feature [cases] present in test data point [True]
# 416 Text feature [2b] present in test data point [True]
# 419 Text feature [2a] present in test data point [True]
# 424 Text feature [single] present in test data point [True]
# 425 Text feature [mammalian] present in test data point [True]
# 432 Text feature [individuals] present in test data point [True]
# 437 Text feature [frame] present in test data point [True]
# 438 Text feature [whereas] present in test data point [True]
# 440 Text feature [patient] present in test data point [True]
# 442 Text feature [clear] present in test data point [True]
# 443 Text feature [information] present in test data point [True]
# 448 Text feature [normal] present in test data point [True]
# 452 Text feature [splice] present in test data point [True]
# 453 Text feature [mutation] present in test data point [True]
# 455 Text feature [activity] present in test data point [True]
# 460 Text feature [lesions] present in test data point [True]
# 464 Text feature [vector] present in test data point [True]
# 468 Text feature [iii] present in test data point [True]
# 470 Text feature [inhibition] present in test data point [True]
# 472 Text feature [16] present in test data point [True]
# 474 Text feature [invitrogen] present in test data point [True]
# 475 Text feature [described] present in test data point [True]
# 481 Text feature [related] present in test data point [True]
# 482 Text feature [less] present in test data point [True]
# 487 Text feature [myc] present in test data point [True]
# 494 Text feature [patients] present in test data point [True]
# 498 Text feature [however] present in test data point [True]
# Out of the top  500  features  89 are present in query point

# %% [markdown]
# # Incorrectly Classified point

# %%
test_point_index = 50
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0054 0.2806 0.0015 0.005  0.0253 0.0196 0.6595 0.0022 0.0008]]
# Actual Class : 2
# --------------------------------------------------
# 13 Text feature [family] present in test data point [True]
# 14 Text feature [context] present in test data point [True]
# 36 Text feature [contrast] present in test data point [True]
# 40 Text feature [factors] present in test data point [True]
# 44 Text feature [consistent] present in test data point [True]
# 61 Text feature [case] present in test data point [True]
# 68 Text feature [reduced] present in test data point [True]
# 77 Text feature [3a] present in test data point [True]
# 85 Text feature [interaction] present in test data point [True]
# 98 Text feature [activation] present in test data point [True]
# 102 Text feature [transformed] present in test data point [True]
# 108 Text feature [found] present in test data point [True]
# 113 Text feature [early] present in test data point [True]
# 117 Text feature [determined] present in test data point [True]
# 124 Text feature [mean] present in test data point [True]
# 133 Text feature [drug] present in test data point [True]
# 137 Text feature [unique] present in test data point [True]
# 139 Text feature [located] present in test data point [True]
# 141 Text feature [nuclear] present in test data point [True]
# 143 Text feature [part] present in test data point [True]
# 144 Text feature [hr] present in test data point [True]
# 160 Text feature [blue] present in test data point [True]
# 184 Text feature [addition] present in test data point [True]
# 189 Text feature [2a] present in test data point [True]
# 192 Text feature [version] present in test data point [True]
# 193 Text feature [absence] present in test data point [True]
# 196 Text feature [complete] present in test data point [True]
# 222 Text feature [many] present in test data point [True]
# 228 Text feature [mrna] present in test data point [True]
# 232 Text feature [confer] present in test data point [True]
# 236 Text feature [involving] present in test data point [True]
# 239 Text feature [database] present in test data point [True]
# 242 Text feature [tumors] present in test data point [True]
# 243 Text feature [pi3k] present in test data point [True]
# 245 Text feature [elevated] present in test data point [True]
# 247 Text feature [overall] present in test data point [True]
# 249 Text feature [percentage] present in test data point [True]
# 258 Text feature [driver] present in test data point [True]
# 261 Text feature [four] present in test data point [True]
# 262 Text feature [comparison] present in test data point [True]
# 272 Text feature [unable] present in test data point [True]
# 274 Text feature [provided] present in test data point [True]
# 275 Text feature [specifically] present in test data point [True]
# 276 Text feature [level] present in test data point [True]
# 277 Text feature [overexpression] present in test data point [True]
# 280 Text feature [interface] present in test data point [True]
# 281 Text feature [sequencing] present in test data point [True]
# 283 Text feature [29] present in test data point [True]
# 284 Text feature [predicted] present in test data point [True]
# 285 Text feature [levels] present in test data point [True]
# 288 Text feature [domains] present in test data point [True]
# 289 Text feature [growth] present in test data point [True]
# 296 Text feature [1999] present in test data point [True]
# 299 Text feature [medium] present in test data point [True]
# 300 Text feature [expected] present in test data point [True]
# 315 Text feature [relative] present in test data point [True]
# 316 Text feature [52] present in test data point [True]
# 319 Text feature [eight] present in test data point [True]
# 329 Text feature [subjected] present in test data point [True]
# 332 Text feature [average] present in test data point [True]
# 338 Text feature [residues] present in test data point [True]
# 340 Text feature [ic50] present in test data point [True]
# 341 Text feature [surface] present in test data point [True]
# 347 Text feature [4a] present in test data point [True]
# 356 Text feature [sensitive] present in test data point [True]
# 369 Text feature [higher] present in test data point [True]
# 370 Text feature [upon] present in test data point [True]
# 372 Text feature [directed] present in test data point [True]
# 373 Text feature [embryonic] present in test data point [True]
# 375 Text feature [mutant] present in test data point [True]
# 376 Text feature [serum] present in test data point [True]
# 382 Text feature [include] present in test data point [True]
# 385 Text feature [protein] present in test data point [True]
# 386 Text feature [known] present in test data point [True]
# 390 Text feature [cells] present in test data point [True]
# 396 Text feature [heterozygous] present in test data point [True]
# 398 Text feature [recent] present in test data point [True]
# 399 Text feature [results] present in test data point [True]
# 400 Text feature [followed] present in test data point [True]
# 403 Text feature [genome] present in test data point [True]
# 407 Text feature [box] present in test data point [True]
# 408 Text feature [http] present in test data point [True]
# 410 Text feature [provide] present in test data point [True]
# 411 Text feature [indicating] present in test data point [True]
# 413 Text feature [wt] present in test data point [True]
# 414 Text feature [result] present in test data point [True]
# 415 Text feature [constitutively] present in test data point [True]
# 416 Text feature [shows] present in test data point [True]
# 418 Text feature [appears] present in test data point [True]
# 421 Text feature [proteins] present in test data point [True]
# 423 Text feature [23] present in test data point [True]
# 424 Text feature [constitutive] present in test data point [True]
# 425 Text feature [together] present in test data point [True]
# 426 Text feature [indicates] present in test data point [True]
# 430 Text feature [frequently] present in test data point [True]
# 444 Text feature [furthermore] present in test data point [True]
# 445 Text feature [sensitivity] present in test data point [True]
# 446 Text feature [occur] present in test data point [True]
# 449 Text feature [sites] present in test data point [True]
# 450 Text feature [biological] present in test data point [True]
# 453 Text feature [according] present in test data point [True]
# 454 Text feature [example] present in test data point [True]
# 457 Text feature [process] present in test data point [True]
# 458 Text feature [24] present in test data point [True]
# 459 Text feature [observations] present in test data point [True]
# 460 Text feature [statistical] present in test data point [True]
# 461 Text feature [without] present in test data point [True]
# 463 Text feature [full] present in test data point [True]
# 464 Text feature [might] present in test data point [True]
# 466 Text feature [different] present in test data point [True]
# 467 Text feature [several] present in test data point [True]
# 470 Text feature [expressing] present in test data point [True]
# 471 Text feature [28] present in test data point [True]
# 472 Text feature [possible] present in test data point [True]
# 474 Text feature [well] present in test data point [True]
# 475 Text feature [line] present in test data point [True]
# 480 Text feature [partial] present in test data point [True]
# 481 Text feature [lines] present in test data point [True]
# 483 Text feature [genetic] present in test data point [True]
# 485 Text feature [sequence] present in test data point [True]
# 490 Text feature [class] present in test data point [True]
# 492 Text feature [assess] present in test data point [True]
# 493 Text feature [18] present in test data point [True]
# 496 Text feature [inhibitory] present in test data point [True]
# 497 Text feature [group] present in test data point [True]
# 498 Text feature [due] present in test data point [True]
# Out of the top  500  features  126 are present in query point

# %% [markdown]
# # Tokenisation using Bow with max features = 3000

# %%
#Count Vectorizer for Gene feature on 1000 top features
gene_vectorizer = CountVectorizer(min_df =3 ,max_features=3000)
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
#Count Vectorizer for Variation feature on 1000 top features
Variation_vectorizer = CountVectorizer(min_df =3,max_features=3000)
train_variation_feature_onehotCoding = Variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = Variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = Variation_vectorizer.transform(cv_df['Variation'])

# %%
Text_vectorizer = CountVectorizer(min_df = 3 , ngram_range=(1, 4),max_features=3000)
train_text_feature_onehotCoding = Text_vectorizer.fit_transform(train_df['TEXT'])
test_text_feature_onehotCoding = Text_vectorizer.transform(test_df['TEXT'])
cv_text_feature_onehotCoding = Text_vectorizer.transform(cv_df['TEXT'])

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
#test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
#cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))

# %% [markdown]
# # Hyper parameter tuning

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1205692673083387
# for alpha = 1e-05
# Log Loss : 1.0391900511789722
# for alpha = 0.0001
# Log Loss : 0.9749669173552424
# for alpha = 0.001
# Log Loss : 1.0269017280754695
# for alpha = 0.01
# Log Loss : 1.2373288698952183
# for alpha = 0.1
# Log Loss : 1.7796900446245505
# for alpha = 1
# Log Loss : 1.8027301694594076
# for alpha = 10
# Log Loss : 1.8049147284807108
# for alpha = 100
# Log Loss : 1.8051728039399386
# For values of best alpha =  0.0001 The train log loss is: 0.6161784744706782
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9749669173552424
# For values of best alpha =  0.0001 The test log loss is: 0.989368050522207

# %% [markdown]
# # **Testing the model with best hyper paramters**

# %%
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 0.9749669173552424
# Number of mis-classified points : 0.31390977443609025
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names1(indices, text, gene, var, no_features):
     
    fea1_len = len(gene_vectorizer.get_feature_names())
    fea2_len = len(Variation_vectorizer.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vectorizer.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = Variation_vectorizer.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = Text_vectorizer.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# # Correctly Classified point

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names1(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[4.200e-03 5.100e-03 4.000e-03 9.500e-03 2.560e-02 9.000e-04 9.485e-01
#   1.900e-03 3.000e-04]]
# Actual Class : 7
# --------------------------------------------------
# 15 Text feature [enhance] present in test data point [True]
# 18 Text feature [transforming] present in test data point [True]
# 24 Text feature [wt] present in test data point [True]
# 27 Text feature [remain] present in test data point [True]
# 42 Text feature [homology] present in test data point [True]
# 44 Text feature [viral] present in test data point [True]
# 48 Text feature [pediatric] present in test data point [True]
# 51 Text feature [transformed] present in test data point [True]
# 55 Text feature [intrinsic] present in test data point [True]
# 66 Text feature [phospho] present in test data point [True]
# 72 Text feature [nude] present in test data point [True]
# 73 Text feature [constitutively] present in test data point [True]
# 81 Text feature [marrow] present in test data point [True]
# 88 Text feature [constitutive] present in test data point [True]
# 90 Text feature [entire] present in test data point [True]
# 92 Text feature [forming] present in test data point [True]
# 93 Text feature [transduced] present in test data point [True]
# 96 Text feature [observations] present in test data point [True]
# 97 Text feature [slightly] present in test data point [True]
# 98 Text feature [codon] present in test data point [True]
# 105 Text feature [enhanced] present in test data point [True]
# 106 Text feature [inhibited] present in test data point [True]
# 107 Text feature [overexpression] present in test data point [True]
# 117 Text feature [downstream] present in test data point [True]
# 119 Text feature [3a] present in test data point [True]
# 120 Text feature [murine] present in test data point [True]
# 123 Text feature [bone] present in test data point [True]
# 134 Text feature [ligand] present in test data point [True]
# 135 Text feature [activated] present in test data point [True]
# 138 Text feature [long] present in test data point [True]
# 139 Text feature [radiation] present in test data point [True]
# 143 Text feature [driven] present in test data point [True]
# 146 Text feature [colonies] present in test data point [True]
# 150 Text feature [receptors] present in test data point [True]
# 152 Text feature [cluster] present in test data point [True]
# 157 Text feature [akt] present in test data point [True]
# 159 Text feature [expressing] present in test data point [True]
# 162 Text feature [leading] present in test data point [True]
# 164 Text feature [oncogenes] present in test data point [True]
# 170 Text feature [heterogeneous] present in test data point [True]
# 174 Text feature [contribute] present in test data point [True]
# 175 Text feature [clearly] present in test data point [True]
# 181 Text feature [distinct] present in test data point [True]
# 184 Text feature [oncogene] present in test data point [True]
# 186 Text feature [open] present in test data point [True]
# 188 Text feature [segment] present in test data point [True]
# 192 Text feature [stably] present in test data point [True]
# 195 Text feature [activation] present in test data point [True]
# 197 Text feature [flt3] present in test data point [True]
# 199 Text feature [probe] present in test data point [True]
# 202 Text feature [transformation] present in test data point [True]
# 205 Text feature [agar] present in test data point [True]
# 206 Text feature [around] present in test data point [True]
# 208 Text feature [must] present in test data point [True]
# 212 Text feature [extracellular] present in test data point [True]
# 217 Text feature [3b] present in test data point [True]
# 219 Text feature [spectrum] present in test data point [True]
# 221 Text feature [locus] present in test data point [True]
# 231 Text feature [14] present in test data point [True]
# 234 Text feature [elevated] present in test data point [True]
# 236 Text feature [mutant] present in test data point [True]
# 239 Text feature [2004] present in test data point [True]
# 242 Text feature [s3] present in test data point [True]
# 244 Text feature [humans] present in test data point [True]
# 252 Text feature [consistently] present in test data point [True]
# 255 Text feature [readily] present in test data point [True]
# 256 Text feature [blot] present in test data point [True]
# 258 Text feature [comparable] present in test data point [True]
# 260 Text feature [screened] present in test data point [True]
# 265 Text feature [along] present in test data point [True]
# 278 Text feature [transiently] present in test data point [True]
# 279 Text feature [properties] present in test data point [True]
# 280 Text feature [bp] present in test data point [True]
# 289 Text feature [capable] present in test data point [True]
# 291 Text feature [leukemia] present in test data point [True]
# 292 Text feature [105] present in test data point [True]
# 302 Text feature [positive] present in test data point [True]
# 303 Text feature [hybridization] present in test data point [True]
# 313 Text feature [factor] present in test data point [True]
# 317 Text feature [cos] present in test data point [True]
# 318 Text feature [tk] present in test data point [True]
# 320 Text feature [inhibitor] present in test data point [True]
# 328 Text feature [free] present in test data point [True]
# 329 Text feature [cancers] present in test data point [True]
# 331 Text feature [conditions] present in test data point [True]
# 333 Text feature [fact] present in test data point [True]
# 335 Text feature [derived] present in test data point [True]
# 336 Text feature [jm] present in test data point [True]
# 337 Text feature [mutants] present in test data point [True]
# 338 Text feature [s1] present in test data point [True]
# 339 Text feature [approximately] present in test data point [True]
# 342 Text feature [presence] present in test data point [True]
# 348 Text feature [transient] present in test data point [True]
# 350 Text feature [cloned] present in test data point [True]
# 353 Text feature [colony] present in test data point [True]
# 360 Text feature [contain] present in test data point [True]
# 361 Text feature [sensitive] present in test data point [True]
# 364 Text feature [common] present in test data point [True]
# 367 Text feature [native] present in test data point [True]
# 371 Text feature [pi3k] present in test data point [True]
# 373 Text feature [phosphotyrosine] present in test data point [True]
# 376 Text feature [epidermal] present in test data point [True]
# 377 Text feature [2a] present in test data point [True]
# 378 Text feature [marked] present in test data point [True]
# 382 Text feature [alanine] present in test data point [True]
# 385 Text feature [phosphorylated] present in test data point [True]
# 389 Text feature [fig] present in test data point [True]
# 391 Text feature [harboring] present in test data point [True]
# 392 Text feature [2b] present in test data point [True]
# 398 Text feature [high] present in test data point [True]
# 400 Text feature [five] present in test data point [True]
# 403 Text feature [components] present in test data point [True]
# 404 Text feature [chromosome] present in test data point [True]
# 407 Text feature [biochemical] present in test data point [True]
# 410 Text feature [concentration] present in test data point [True]
# 413 Text feature [clone] present in test data point [True]
# 414 Text feature [24] present in test data point [True]
# 422 Text feature [higher] present in test data point [True]
# 424 Text feature [respectively] present in test data point [True]
# 425 Text feature [absence] present in test data point [True]
# 430 Text feature [previously] present in test data point [True]
# 431 Text feature [figs] present in test data point [True]
# 434 Text feature [regions] present in test data point [True]
# 435 Text feature [outcome] present in test data point [True]
# 443 Text feature [transduction] present in test data point [True]
# 445 Text feature [specimens] present in test data point [True]
# 449 Text feature [subsequent] present in test data point [True]
# 450 Text feature [far] present in test data point [True]
# 452 Text feature [represent] present in test data point [True]
# 453 Text feature [translation] present in test data point [True]
# 460 Text feature [effective] present in test data point [True]
# 464 Text feature [liver] present in test data point [True]
# 465 Text feature [toward] present in test data point [True]
# 466 Text feature [location] present in test data point [True]
# 469 Text feature [anchorage] present in test data point [True]
# 474 Text feature [addition] present in test data point [True]
# 477 Text feature [reverse] present in test data point [True]
# 478 Text feature [12] present in test data point [True]
# 480 Text feature [growth] present in test data point [True]
# 481 Text feature [insertions] present in test data point [True]
# 482 Text feature [kinases] present in test data point [True]
# 485 Text feature [mechanisms] present in test data point [True]
# 486 Text feature [hematopoietic] present in test data point [True]
# 494 Text feature [293t] present in test data point [True]
# 495 Text feature [could] present in test data point [True]
# 498 Text feature [activate] present in test data point [True]
# Out of the top  500  features  146 are present in query point

# %% [markdown]
# # Incorrectly Classified point

# %%
test_point_index = 500
no_feature = 1500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names1(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[7.005e-01 6.000e-04 0.000e+00 2.873e-01 1.200e-03 2.000e-04 9.500e-03
#   5.000e-04 2.000e-04]]
# Actual Class : 4
# --------------------------------------------------
# 5 Text feature [aggregation] present in test data point [True]
# 10 Text feature [lysate] present in test data point [True]
# 12 Text feature [processing] present in test data point [True]
# 16 Text feature [mapping] present in test data point [True]
# 20 Text feature [surface] present in test data point [True]
# 29 Text feature [dbd] present in test data point [True]
# 33 Text feature [peptides] present in test data point [True]
# 40 Text feature [middle] present in test data point [True]
# 41 Text feature [translational] present in test data point [True]
# 46 Text feature [hydrophobic] present in test data point [True]
# 51 Text feature [reactions] present in test data point [True]
# 56 Text feature [affecting] present in test data point [True]
# 57 Text feature [complexes] present in test data point [True]
# 59 Text feature [deficient] present in test data point [True]
# 66 Text feature [exist] present in test data point [True]
# 68 Text feature [3d] present in test data point [True]
# 71 Text feature [translation] present in test data point [True]
# 72 Text feature [verified] present in test data point [True]
# 76 Text feature [panel] present in test data point [True]
# 78 Text feature [influence] present in test data point [True]
# 84 Text feature [alter] present in test data point [True]
# 90 Text feature [mapped] present in test data point [True]
# 91 Text feature [rt] present in test data point [True]
# 92 Text feature [detectable] present in test data point [True]
# 93 Text feature [areas] present in test data point [True]
# 96 Text feature [novel] present in test data point [True]
# 101 Text feature [upon] present in test data point [True]
# 107 Text feature [reduction] present in test data point [True]
# 112 Text feature [cultures] present in test data point [True]
# 115 Text feature [interacting] present in test data point [True]
# 116 Text feature [additionally] present in test data point [True]
# 118 Text feature [degree] present in test data point [True]
# 119 Text feature [acids] present in test data point [True]
# 120 Text feature [molecules] present in test data point [True]
# 126 Text feature [arrest] present in test data point [True]
# 129 Text feature [4d] present in test data point [True]
# 131 Text feature [chain] present in test data point [True]
# 136 Text feature [temperature] present in test data point [True]
# 137 Text feature [next] present in test data point [True]
# 138 Text feature [infected] present in test data point [True]
# 140 Text feature [importantly] present in test data point [True]
# 146 Text feature [affect] present in test data point [True]
# 147 Text feature [mediates] present in test data point [True]
# 151 Text feature [bovine] present in test data point [True]
# 152 Text feature [defects] present in test data point [True]
# 154 Text feature [thereby] present in test data point [True]
# 160 Text feature [calculated] present in test data point [True]
# 161 Text feature [hotspot] present in test data point [True]
# 162 Text feature [particularly] present in test data point [True]
# 163 Text feature [specificity] present in test data point [True]
# 165 Text feature [exposed] present in test data point [True]
# 166 Text feature [cultured] present in test data point [True]
# 167 Text feature [labeled] present in test data point [True]
# 168 Text feature [order] present in test data point [True]
# 169 Text feature [define] present in test data point [True]
# 173 Text feature [reduce] present in test data point [True]
# 179 Text feature [peptide] present in test data point [True]
# 181 Text feature [exposure] present in test data point [True]
# 184 Text feature [contribution] present in test data point [True]
# 185 Text feature [methionine] present in test data point [True]
# 186 Text feature [directed] present in test data point [True]
# 188 Text feature [stress] present in test data point [True]
# 189 Text feature [subjected] present in test data point [True]
# 191 Text feature [extent] present in test data point [True]
# 193 Text feature [makes] present in test data point [True]
# 194 Text feature [reveal] present in test data point [True]
# 197 Text feature [display] present in test data point [True]
# 199 Text feature [mutational] present in test data point [True]
# 201 Text feature [version] present in test data point [True]
# 202 Text feature [carrying] present in test data point [True]
# 204 Text feature [matched] present in test data point [True]
# 205 Text feature [page] present in test data point [True]
# 206 Text feature [partially] present in test data point [True]
# 211 Text feature [consistently] present in test data point [True]
# 212 Text feature [21] present in test data point [True]
# 213 Text feature [agarose] present in test data point [True]
# 215 Text feature [latter] present in test data point [True]
# 218 Text feature [encoding] present in test data point [True]
# 225 Text feature [located] present in test data point [True]
# 227 Text feature [immunoprecipitation] present in test data point [True]
# 228 Text feature [deletion] present in test data point [True]
# 231 Text feature [find] present in test data point [True]
# 235 Text feature [sds] present in test data point [True]
# 236 Text feature [analyzed] present in test data point [True]
# 237 Text feature [loss] present in test data point [True]
# 238 Text feature [technologies] present in test data point [True]
# 243 Text feature [least] present in test data point [True]
# 250 Text feature [structure] present in test data point [True]
# 251 Text feature [includes] present in test data point [True]
# 253 Text feature [uv] present in test data point [True]
# 255 Text feature [conducted] present in test data point [True]
# 256 Text feature [identify] present in test data point [True]
# 257 Text feature [damaging] present in test data point [True]
# 259 Text feature [position] present in test data point [True]
# 261 Text feature [constructs] present in test data point [True]
# 266 Text feature [49] present in test data point [True]
# 267 Text feature [roche] present in test data point [True]
# 269 Text feature [mediate] present in test data point [True]
# 271 Text feature [function] present in test data point [True]
# 272 Text feature [2004] present in test data point [True]
# 273 Text feature [analyses] present in test data point [True]
# 283 Text feature [05] present in test data point [True]
# 284 Text feature [reporter] present in test data point [True]
# 285 Text feature [fluorescent] present in test data point [True]
# 287 Text feature [bcl] present in test data point [True]
# 288 Text feature [sequences] present in test data point [True]
# 291 Text feature [lysates] present in test data point [True]
# 292 Text feature [screened] present in test data point [True]
# 298 Text feature [smaller] present in test data point [True]
# 300 Text feature [dependent] present in test data point [True]
# 301 Text feature [2002] present in test data point [True]
# 302 Text feature [bim] present in test data point [True]
# 303 Text feature [1d] present in test data point [True]
# 306 Text feature [via] present in test data point [True]
# 307 Text feature [contact] present in test data point [True]
# 309 Text feature [folding] present in test data point [True]
# 311 Text feature [2001] present in test data point [True]
# 313 Text feature [hct116] present in test data point [True]
# 315 Text feature [last] present in test data point [True]
# 320 Text feature [allowed] present in test data point [True]
# 324 Text feature [value] present in test data point [True]
# 327 Text feature [issue] present in test data point [True]
# 329 Text feature [parallel] present in test data point [True]
# 330 Text feature [corresponding] present in test data point [True]
# 331 Text feature [p21] present in test data point [True]
# 334 Text feature [conserved] present in test data point [True]
# 340 Text feature [side] present in test data point [True]
# 341 Text feature [42] present in test data point [True]
# 344 Text feature [2d] present in test data point [True]
# 346 Text feature [panels] present in test data point [True]
# 347 Text feature [appear] present in test data point [True]
# 348 Text feature [produced] present in test data point [True]
# 349 Text feature [predicted] present in test data point [True]
# 350 Text feature [truncating] present in test data point [True]
# 352 Text feature [reduced] present in test data point [True]
# 359 Text feature [revealed] present in test data point [True]
# 372 Text feature [2006] present in test data point [True]
# 375 Text feature [regulatory] present in test data point [True]
# 377 Text feature [length] present in test data point [True]
# 382 Text feature [localized] present in test data point [True]
# 383 Text feature [purification] present in test data point [True]
# 393 Text feature [individual] present in test data point [True]
# 396 Text feature [efficiently] present in test data point [True]
# 399 Text feature [species] present in test data point [True]
# 402 Text feature [type] present in test data point [True]
# 406 Text feature [500] present in test data point [True]
# 408 Text feature [interacts] present in test data point [True]
# 409 Text feature [consensus] present in test data point [True]
# 412 Text feature [intracellular] present in test data point [True]
# 415 Text feature [phosphate] present in test data point [True]
# 416 Text feature [xl] present in test data point [True]
# 427 Text feature [six] present in test data point [True]
# 429 Text feature [context] present in test data point [True]
# 431 Text feature [investigated] present in test data point [True]
# 432 Text feature [diverse] present in test data point [True]
# 435 Text feature [complex] present in test data point [True]
# 436 Text feature [synthesis] present in test data point [True]
# 438 Text feature [derived] present in test data point [True]
# 440 Text feature [ref] present in test data point [True]
# 441 Text feature [binds] present in test data point [True]
# 442 Text feature [polymorphism] present in test data point [True]
# 445 Text feature [negatively] present in test data point [True]
# 446 Text feature [displayed] present in test data point [True]
# 448 Text feature [32] present in test data point [True]
# 450 Text feature [error] present in test data point [True]
# 451 Text feature [future] present in test data point [True]
# 452 Text feature [backbone] present in test data point [True]
# 453 Text feature [effect] present in test data point [True]
# 459 Text feature [total] present in test data point [True]
# 461 Text feature [abrogated] present in test data point [True]
# 465 Text feature [transcriptional] present in test data point [True]
# 468 Text feature [close] present in test data point [True]
# 469 Text feature [types] present in test data point [True]
# 470 Text feature [established] present in test data point [True]
# 479 Text feature [structural] present in test data point [True]
# 480 Text feature [central] present in test data point [True]
# 483 Text feature [local] present in test data point [True]
# 484 Text feature [provided] present in test data point [True]
# 488 Text feature [plays] present in test data point [True]
# 489 Text feature [1a] present in test data point [True]
# 490 Text feature [therefore] present in test data point [True]
# 492 Text feature [broad] present in test data point [True]
# 493 Text feature [identified] present in test data point [True]
# 500 Text feature [chains] present in test data point [True]
# 501 Text feature [binding] present in test data point [True]
# 502 Text feature [signal] present in test data point [True]
# 503 Text feature [1b] present in test data point [True]
# 504 Text feature [like] present in test data point [True]
# 509 Text feature [structurally] present in test data point [True]
# 512 Text feature [amino] present in test data point [True]
# 516 Text feature [transiently] present in test data point [True]
# 517 Text feature [leads] present in test data point [True]
# 523 Text feature [51] present in test data point [True]
# 525 Text feature [null] present in test data point [True]
# 526 Text feature [relative] present in test data point [True]
# 527 Text feature [modeling] present in test data point [True]
# 530 Text feature [p53] present in test data point [True]
# 534 Text feature [significantly] present in test data point [True]
# 535 Text feature [particular] present in test data point [True]
# 536 Text feature [providing] present in test data point [True]
# 537 Text feature [expression] present in test data point [True]
# 542 Text feature [modification] present in test data point [True]
# 543 Text feature [75] present in test data point [True]
# 545 Text feature [36] present in test data point [True]
# 548 Text feature [modifications] present in test data point [True]
# 551 Text feature [wild] present in test data point [True]
# 552 Text feature [mefs] present in test data point [True]
# 553 Text feature [2005] present in test data point [True]
# 555 Text feature [area] present in test data point [True]
# 560 Text feature [knockdown] present in test data point [True]
# 561 Text feature [others] present in test data point [True]
# 564 Text feature [30] present in test data point [True]
# 569 Text feature [46] present in test data point [True]
# 570 Text feature [biology] present in test data point [True]
# 572 Text feature [sufficient] present in test data point [True]
# 574 Text feature [atm] present in test data point [True]
# 575 Text feature [gene] present in test data point [True]
# 576 Text feature [one] present in test data point [True]
# 577 Text feature [pdb] present in test data point [True]
# 578 Text feature [nt] present in test data point [True]
# 581 Text feature [25] present in test data point [True]
# 582 Text feature [knowledge] present in test data point [True]
# 583 Text feature [defined] present in test data point [True]
# 584 Text feature [crystal] present in test data point [True]
# 585 Text feature [induce] present in test data point [True]
# 590 Text feature [toward] present in test data point [True]
# 593 Text feature [evidence] present in test data point [True]
# 594 Text feature [72] present in test data point [True]
# 597 Text feature [interact] present in test data point [True]
# 600 Text feature [independently] present in test data point [True]
# 604 Text feature [1c] present in test data point [True]
# 605 Text feature [ability] present in test data point [True]
# 606 Text feature [previous] present in test data point [True]
# 612 Text feature [sirna] present in test data point [True]
# 613 Text feature [showing] present in test data point [True]
# 617 Text feature [37] present in test data point [True]
# 623 Text feature [disrupted] present in test data point [True]
# 624 Text feature [codon] present in test data point [True]
# 625 Text feature [epitope] present in test data point [True]
# 630 Text feature [equal] present in test data point [True]
# 631 Text feature [general] present in test data point [True]
# 635 Text feature [incubated] present in test data point [True]
# 636 Text feature [indicated] present in test data point [True]
# 643 Text feature [loci] present in test data point [True]
# 647 Text feature [patterns] present in test data point [True]
# 648 Text feature [6b] present in test data point [True]
# 649 Text feature [extended] present in test data point [True]
# 653 Text feature [obtained] present in test data point [True]
# 660 Text feature [3c] present in test data point [True]
# 662 Text feature [120] present in test data point [True]
# 664 Text feature [measurements] present in test data point [True]
# 668 Text feature [conditions] present in test data point [True]
# 671 Text feature [immunoprecipitated] present in test data point [True]
# 675 Text feature [infection] present in test data point [True]
# 677 Text feature [loading] present in test data point [True]
# 678 Text feature [common] present in test data point [True]
# 680 Text feature [pcr] present in test data point [True]
# 683 Text feature [question] present in test data point [True]
# 688 Text feature [breast] present in test data point [True]
# 691 Text feature [present] present in test data point [True]
# 698 Text feature [inactivated] present in test data point [True]
# 700 Text feature [protein] present in test data point [True]
# 720 Text feature [western] present in test data point [True]
# 721 Text feature [vectors] present in test data point [True]
# 722 Text feature [commonly] present in test data point [True]
# 724 Text feature [conversely] present in test data point [True]
# 725 Text feature [mutation] present in test data point [True]
# 728 Text feature [supp] present in test data point [True]
# 731 Text feature [five] present in test data point [True]
# 732 Text feature [details] present in test data point [True]
# 734 Text feature [stained] present in test data point [True]
# 737 Text feature [limited] present in test data point [True]
# 740 Text feature [furthermore] present in test data point [True]
# 743 Text feature [kd] present in test data point [True]
# 745 Text feature [level] present in test data point [True]
# 748 Text feature [allele] present in test data point [True]
# 750 Text feature [non] present in test data point [True]
# 751 Text feature [occurred] present in test data point [True]
# 752 Text feature [100] present in test data point [True]
# 754 Text feature [primarily] present in test data point [True]
# 755 Text feature [dna] present in test data point [True]
# 756 Text feature [responses] present in test data point [True]
# 757 Text feature [major] present in test data point [True]
# 759 Text feature [another] present in test data point [True]
# 760 Text feature [confirming] present in test data point [True]
# 764 Text feature [domains] present in test data point [True]
# 765 Text feature [efficient] present in test data point [True]
# 770 Text feature [systems] present in test data point [True]
# 773 Text feature [inactivation] present in test data point [True]
# 774 Text feature [whether] present in test data point [True]
# 775 Text feature [16] present in test data point [True]
# 777 Text feature [perhaps] present in test data point [True]
# 778 Text feature [essential] present in test data point [True]
# 784 Text feature [antigen] present in test data point [True]
# 786 Text feature [22] present in test data point [True]
# 791 Text feature [lacking] present in test data point [True]
# 792 Text feature [sequence] present in test data point [True]
# 794 Text feature [94] present in test data point [True]
# 795 Text feature [additional] present in test data point [True]
# 797 Text feature [vitro] present in test data point [True]
# 798 Text feature [1999] present in test data point [True]
# 801 Text feature [localization] present in test data point [True]
# 803 Text feature [entire] present in test data point [True]
# 804 Text feature [directly] present in test data point [True]
# 805 Text feature [contain] present in test data point [True]
# 807 Text feature [note] present in test data point [True]
# 811 Text feature [pocket] present in test data point [True]
# 812 Text feature [larger] present in test data point [True]
# 814 Text feature [together] present in test data point [True]
# 815 Text feature [prostate] present in test data point [True]
# 816 Text feature [selected] present in test data point [True]
# 818 Text feature [functions] present in test data point [True]
# 819 Text feature [media] present in test data point [True]
# 820 Text feature [hospital] present in test data point [True]
# 822 Text feature [incubation] present in test data point [True]
# 823 Text feature [left] present in test data point [True]
# 827 Text feature [staining] present in test data point [True]
# 828 Text feature [formed] present in test data point [True]
# 831 Text feature [minimal] present in test data point [True]
# 834 Text feature [assess] present in test data point [True]
# 835 Text feature [85] present in test data point [True]
# 836 Text feature [unique] present in test data point [True]
# 841 Text feature [either] present in test data point [True]
# 843 Text feature [determined] present in test data point [True]
# 844 Text feature [studies] present in test data point [True]
# 851 Text feature [affected] present in test data point [True]
# 853 Text feature [early] present in test data point [True]
# 855 Text feature [size] present in test data point [True]
# 859 Text feature [poorly] present in test data point [True]
# 863 Text feature [alternatively] present in test data point [True]
# 864 Text feature [represents] present in test data point [True]
# 865 Text feature [selection] present in test data point [True]
# 867 Text feature [43] present in test data point [True]
# 869 Text feature [39] present in test data point [True]
# 870 Text feature [different] present in test data point [True]
# 872 Text feature [normally] present in test data point [True]
# 873 Text feature [effects] present in test data point [True]
# 874 Text feature [confirmed] present in test data point [True]
# 875 Text feature [negative] present in test data point [True]
# 877 Text feature [blot] present in test data point [True]
# 878 Text feature [remaining] present in test data point [True]
# 882 Text feature [retained] present in test data point [True]
# 884 Text feature [followed] present in test data point [True]
# 888 Text feature [transcription] present in test data point [True]
# 894 Text feature [within] present in test data point [True]
# 896 Text feature [2003] present in test data point [True]
# 898 Text feature [impaired] present in test data point [True]
# 899 Text feature [nearly] present in test data point [True]
# 900 Text feature [referred] present in test data point [True]
# 902 Text feature [nuclear] present in test data point [True]
# 909 Text feature [suppressor] present in test data point [True]
# 910 Text feature [resulted] present in test data point [True]
# 911 Text feature [containing] present in test data point [True]
# 913 Text feature [found] present in test data point [True]
# 918 Text feature [potentially] present in test data point [True]
# 925 Text feature [proteins] present in test data point [True]
# 933 Text feature [fig] present in test data point [True]
# 936 Text feature [best] present in test data point [True]
# 938 Text feature [involving] present in test data point [True]
# 942 Text feature [completely] present in test data point [True]
# 948 Text feature [promoter] present in test data point [True]
# 954 Text feature [core] present in test data point [True]
# 957 Text feature [trypsin] present in test data point [True]
# 958 Text feature [cancer] present in test data point [True]
# 959 Text feature [medium] present in test data point [True]
# 960 Text feature [notably] present in test data point [True]
# 963 Text feature [integrity] present in test data point [True]
# 966 Text feature [relevance] present in test data point [True]
# 969 Text feature [indeed] present in test data point [True]
# 970 Text feature [could] present in test data point [True]
# 974 Text feature [gst] present in test data point [True]
# 976 Text feature [specific] present in test data point [True]
# 978 Text feature [presence] present in test data point [True]
# 979 Text feature [many] present in test data point [True]
# 980 Text feature [interest] present in test data point [True]
# 983 Text feature [portion] present in test data point [True]
# 986 Text feature [full] present in test data point [True]
# 988 Text feature [construct] present in test data point [True]
# 989 Text feature [genetic] present in test data point [True]
# 993 Text feature [insights] present in test data point [True]
# 997 Text feature [vivo] present in test data point [True]
# 1000 Text feature [agents] present in test data point [True]
# 1006 Text feature [homology] present in test data point [True]
# 1007 Text feature [years] present in test data point [True]
# 1010 Text feature [statistically] present in test data point [True]
# 1013 Text feature [bearing] present in test data point [True]
# 1015 Text feature [treated] present in test data point [True]
# 1016 Text feature [values] present in test data point [True]
# 1018 Text feature [23] present in test data point [True]
# 1020 Text feature [translocation] present in test data point [True]
# 1022 Text feature [tumors] present in test data point [True]
# 1023 Text feature [measured] present in test data point [True]
# 1025 Text feature [5b] present in test data point [True]
# 1026 Text feature [antibodies] present in test data point [True]
# 1029 Text feature [predominantly] present in test data point [True]
# 1031 Text feature [fold] present in test data point [True]
# 1036 Text feature [promega] present in test data point [True]
# 1037 Text feature [remained] present in test data point [True]
# 1038 Text feature [role] present in test data point [True]
# 1042 Text feature [technology] present in test data point [True]
# 1043 Text feature [large] present in test data point [True]
# 1048 Text feature [include] present in test data point [True]
# 1051 Text feature [greater] present in test data point [True]
# 1052 Text feature [control] present in test data point [True]
# 1053 Text feature [line] present in test data point [True]
# 1054 Text feature [buried] present in test data point [True]
# 1059 Text feature [key] present in test data point [True]
# 1060 Text feature [needed] present in test data point [True]
# 1064 Text feature [average] present in test data point [True]
# 1065 Text feature [17] present in test data point [True]
# 1067 Text feature [interactions] present in test data point [True]
# 1069 Text feature [implicated] present in test data point [True]
# 1070 Text feature [among] present in test data point [True]
# 1073 Text feature [involved] present in test data point [True]
# 1074 Text feature [structures] present in test data point [True]
# 1076 Text feature [caspase] present in test data point [True]
# 1077 Text feature [human] present in test data point [True]
# 1078 Text feature [added] present in test data point [True]
# 1079 Text feature [weak] present in test data point [True]
# 1080 Text feature [cdk] present in test data point [True]
# 1084 Text feature [acid] present in test data point [True]
# 1086 Text feature [analyze] present in test data point [True]
# 1088 Text feature [cellular] present in test data point [True]
# 1093 Text feature [induces] present in test data point [True]
# 1094 Text feature [chromatin] present in test data point [True]
# 1099 Text feature [lead] present in test data point [True]
# 1100 Text feature [related] present in test data point [True]
# 1102 Text feature [understanding] present in test data point [True]
# 1107 Text feature [second] present in test data point [True]
# 1111 Text feature [light] present in test data point [True]
# 1112 Text feature [work] present in test data point [True]
# 1114 Text feature [red] present in test data point [True]
# 1115 Text feature [19] present in test data point [True]
# 1117 Text feature [shrna] present in test data point [True]
# 1120 Text feature [included] present in test data point [True]
# 1121 Text feature [pre] present in test data point [True]
# 1123 Text feature [flow] present in test data point [True]
# 1124 Text feature [2c] present in test data point [True]
# 1130 Text feature [schematic] present in test data point [True]
# 1132 Text feature [unknown] present in test data point [True]
# 1134 Text feature [52] present in test data point [True]
# 1138 Text feature [g1] present in test data point [True]
# 1140 Text feature [clear] present in test data point [True]
# 1146 Text feature [actin] present in test data point [True]
# 1149 Text feature [al] present in test data point [True]
# 1150 Text feature [approach] present in test data point [True]
# 1151 Text feature [cytometry] present in test data point [True]
# 1153 Text feature [genes] present in test data point [True]
# 1155 Text feature [et] present in test data point [True]
# 1159 Text feature [figures] present in test data point [True]
# 1160 Text feature [alanine] present in test data point [True]
# 1163 Text feature [classical] present in test data point [True]
# 1165 Text feature [62] present in test data point [True]
# 1167 Text feature [invitrogen] present in test data point [True]
# 1172 Text feature [alignment] present in test data point [True]
# 1173 Text feature [accessible] present in test data point [True]
# 1175 Text feature [performed] present in test data point [True]
# 1178 Text feature [mdm2] present in test data point [True]
# 1182 Text feature [charge] present in test data point [True]
# 1188 Text feature [cells] present in test data point [True]
# 1190 Text feature [suggests] present in test data point [True]
# 1191 Text feature [fetal] present in test data point [True]
# 1194 Text feature [13] present in test data point [True]
# 1195 Text feature [current] present in test data point [True]
# 1196 Text feature [capable] present in test data point [True]
# 1197 Text feature [samples] present in test data point [True]
# 1198 Text feature [understand] present in test data point [True]
# 1200 Text feature [selective] present in test data point [True]
# 1202 Text feature [regulating] present in test data point [True]
# 1203 Text feature [tested] present in test data point [True]
# 1205 Text feature [specifically] present in test data point [True]
# 1212 Text feature [mrna] present in test data point [True]
# 1215 Text feature [majority] present in test data point [True]
# 1219 Text feature [parp] present in test data point [True]
# 1220 Text feature [less] present in test data point [True]
# 1224 Text feature [factors] present in test data point [True]
# 1225 Text feature [correlate] present in test data point [True]
# 1226 Text feature [extensive] present in test data point [True]
# 1227 Text feature [family] present in test data point [True]
# 1230 Text feature [rapid] present in test data point [True]
# 1238 Text feature [fixed] present in test data point [True]
# 1245 Text feature [mechanisms] present in test data point [True]
# 1246 Text feature [provide] present in test data point [True]
# 1248 Text feature [92] present in test data point [True]
# 1251 Text feature [leading] present in test data point [True]
# 1252 Text feature [1993] present in test data point [True]
# 1256 Text feature [1994] present in test data point [True]
# 1259 Text feature [table] present in test data point [True]
# 1261 Text feature [correlated] present in test data point [True]
# 1262 Text feature [created] present in test data point [True]
# 1267 Text feature [blocks] present in test data point [True]
# 1273 Text feature [manner] present in test data point [True]
# 1277 Text feature [ligand] present in test data point [True]
# 1278 Text feature [might] present in test data point [True]
# 1283 Text feature [reveals] present in test data point [True]
# 1284 Text feature [transfected] present in test data point [True]
# 1285 Text feature [mutagenesis] present in test data point [True]
# 1286 Text feature [ml] present in test data point [True]
# 1288 Text feature [receptor] present in test data point [True]
# 1290 Text feature [confirm] present in test data point [True]
# 1293 Text feature [member] present in test data point [True]
# 1296 Text feature [help] present in test data point [True]
# 1297 Text feature [terminal] present in test data point [True]
# 1300 Text feature [31] present in test data point [True]
# 1302 Text feature [instructions] present in test data point [True]
# 1304 Text feature [whole] present in test data point [True]
# 1306 Text feature [however] present in test data point [True]
# 1311 Text feature [disrupt] present in test data point [True]
# 1315 Text feature [noted] present in test data point [True]
# 1316 Text feature [modest] present in test data point [True]
# 1318 Text feature [true] present in test data point [True]
# 1322 Text feature [shift] present in test data point [True]
# 1324 Text feature [virus] present in test data point [True]
# 1328 Text feature [right] present in test data point [True]
# 1329 Text feature [evaluated] present in test data point [True]
# 1335 Text feature [longer] present in test data point [True]
# 1337 Text feature [arg] present in test data point [True]
# 1340 Text feature [lane] present in test data point [True]
# 1341 Text feature [address] present in test data point [True]
# 1343 Text feature [cell] present in test data point [True]
# 1344 Text feature [compare] present in test data point [True]
# 1349 Text feature [mechanism] present in test data point [True]
# 1350 Text feature [activates] present in test data point [True]
# 1351 Text feature [combination] present in test data point [True]
# 1353 Text feature [nm] present in test data point [True]
# 1355 Text feature [11] present in test data point [True]
# 1356 Text feature [view] present in test data point [True]
# 1359 Text feature [anti] present in test data point [True]
# 1360 Text feature [chip] present in test data point [True]
# 1361 Text feature [changes] present in test data point [True]
# 1362 Text feature [result] present in test data point [True]
# 1364 Text feature [4c] present in test data point [True]
# 1366 Text feature [contacts] present in test data point [True]
# 1370 Text feature [linked] present in test data point [True]
# 1374 Text feature [assay] present in test data point [True]
# 1376 Text feature [suppression] present in test data point [True]
# 1378 Text feature [independent] present in test data point [True]
# 1380 Text feature [stages] present in test data point [True]
# 1381 Text feature [recombinant] present in test data point [True]
# 1382 Text feature [association] present in test data point [True]
# 1386 Text feature [applied] present in test data point [True]
# 1391 Text feature [complete] present in test data point [True]
# 1393 Text feature [3a] present in test data point [True]
# 1398 Text feature [inhibiting] present in test data point [True]
# 1401 Text feature [taken] present in test data point [True]
# 1406 Text feature [lncap] present in test data point [True]
# 1409 Text feature [assessed] present in test data point [True]
# 1411 Text feature [based] present in test data point [True]
# 1412 Text feature [members] present in test data point [True]
# 1413 Text feature [clearly] present in test data point [True]
# 1415 Text feature [targeting] present in test data point [True]
# 1416 Text feature [coupled] present in test data point [True]
# 1418 Text feature [induction] present in test data point [True]
# 1419 Text feature [partial] present in test data point [True]
# 1420 Text feature [possible] present in test data point [True]
# 1422 Text feature [recently] present in test data point [True]
# 1423 Text feature [supplemented] present in test data point [True]
# 1424 Text feature [outside] present in test data point [True]
# 1428 Text feature [18] present in test data point [True]
# 1433 Text feature [supplemental] present in test data point [True]
# 1434 Text feature [possibility] present in test data point [True]
# 1435 Text feature [mouse] present in test data point [True]
# 1437 Text feature [class] present in test data point [True]
# 1440 Text feature [allow] present in test data point [True]
# 1441 Text feature [56] present in test data point [True]
# 1443 Text feature [procedures] present in test data point [True]
# 1446 Text feature [segment] present in test data point [True]
# 1447 Text feature [often] present in test data point [True]
# 1450 Text feature [histone] present in test data point [True]
# 1455 Text feature [potential] present in test data point [True]
# 1457 Text feature [bind] present in test data point [True]
# 1460 Text feature [lack] present in test data point [True]
# 1461 Text feature [34] present in test data point [True]
# 1466 Text feature [addition] present in test data point [True]
# 1468 Text feature [yet] present in test data point [True]
# 1470 Text feature [affects] present in test data point [True]
# 1471 Text feature [also] present in test data point [True]
# 1473 Text feature [blotting] present in test data point [True]
# 1482 Text feature [failure] present in test data point [True]
# 1495 Text feature [versus] present in test data point [True]
# 1496 Text feature [lysed] present in test data point [True]
# Out of the top  1500  features  581 are present in query point

# %% [markdown]
# # Conclusion and Activities

# %% [markdown]
# Following are the activities that has been performed in this assignment :-
#
# 1) We have worked here on personalised cancer diagnosis by load training varaints , training text file from kaggle
#
# 2)Performed below Preprocessig on this data set :-
#     a)we have removed the special character
#     b)we have removed the stop words
#     c)we have replaced multiple spaces with single spaces
#
# 3) We found there are three features - Genes, Variations , Text based on which we have to predict the class , therefore we performed univariate analysis on these features
#
# 4)We used our confusion , Precision , recall matrix for the analysis which helped which feature is more contrubuting towards the prediction.
#
# 5)We have taken tfidf vectorizer  with max features = 1000 and performed different model on it and later compared all the models based on there log loss and misclassification percentage
#
# 6)We have also performed count vectorizer using unigram and bigram for logistic regression and also compared the same with the tfidf vectorizer on the same table.

# %% [markdown]
# Results have been compared in the following table:-

# %%
# Please compare all your models using Prettytable library
from prettytable import PrettyTable
x = PrettyTable()
print("="*40,"Log Loss for different Models","="*40)
x.field_names = ["Sl_No", "Model", "Hyperparameter", "Train_Loss","Cv_Loss","Test Loss","Misclassification%"]
x.add_row([1, "Naive Bayes", 0.001,0.7559,1.1437,1.2218,39.4])
x.add_row([2, "KNN",11, 0.6213,0.9849,1.0989,35.71])
x.add_row([3, "Log-Reg with Balanced Class Weight", 0.0001,0.56,0.955,1.028,33.08])
x.add_row([4, "Log-Reg without Balanced Class Weight", 0.0001,0.56,0.997,1.0523,33.45])
x.add_row([5, "Linear SVM", 0.01,0.678,1.0288,1.107,33])
x.add_row([6, "RF", 500,0.846,1.44,1.23,41])
x.add_row([7, "RF With Response Coding", 100,0.06,1.31,1.35,47])
x.add_row([8, "Naive Bayes", 0.001,0.7559,1.1437,1.2218,39.4])
x.add_row([9, "Stackin NB, Log-reg, linear SVM", 1,0.8,1.10,1.18,40])
x.add_row([11, "Maximum Voting NB, Log-reg, linear SVM", "-" ,0.75,1.15,1.22,39])
x.add_row([12, "lOG-Reg on unigram Count Vectorizer",0.0001 ,0.602,1.05,0.999,34.5])
x.add_row([13, "lOG-Reg on bigram Count Vectorizer",0.0001 ,0.609,1.045,1.005,34.5])  
x.add_row([13, "lOG-Reg on n-gram 3000 features Count Vectorizer",0.0001 ,0.44,0.97,0.98,31.3])  
print(x)
# Out:
# ======================================== Log Loss for different Models ========================================
# +-------+--------------------------------------------------+----------------+------------+---------+-----------+--------------------+
# | Sl_No |                      Model                       | Hyperparameter | Train_Loss | Cv_Loss | Test Loss | Misclassification% |
# +-------+--------------------------------------------------+----------------+------------+---------+-----------+--------------------+
# |   1   |                   Naive Bayes                    |     0.001      |   0.7559   |  1.1437 |   1.2218  |        39.4        |
# |   2   |                       KNN                        |       11       |   0.6213   |  0.9849 |   1.0989  |       35.71        |
# |   3   |        Log-Reg with Balanced Class Weight        |     0.0001     |    0.56    |  0.955  |   1.028   |       33.08        |
# |   4   |      Log-Reg without Balanced Class Weight       |     0.0001     |    0.56    |  0.997  |   1.0523  |       33.45        |
# |   5   |                    Linear SVM                    |      0.01      |   0.678    |  1.0288 |   1.107   |         33         |
# |   6   |                        RF                        |      500       |   0.846    |   1.44  |    1.23   |         41         |
# |   7   |             RF With Response Coding              |      100       |    0.06    |   1.31  |    1.35   |         47         |
# |   8   |                   Naive Bayes                    |     0.001      |   0.7559   |  1.1437 |   1.2218  |        39.4        |
# |   9   |         Stackin NB, Log-reg, linear SVM          |       1        |    0.8     |   1.1   |    1.18   |         40         |
# |   11  |      Maximum Voting NB, Log-reg, linear SVM      |       -        |    0.75    |   1.15  |    1.22   |         39         |
# |   12  |       lOG-Reg on unigram Count Vectorizer        |     0.0001     |   0.602    |   1.05  |   0.999   |        34.5        |
# |   13  |        lOG-Reg on bigram Count Vectorizer        |     0.0001     |   0.609    |  1.045  |   1.005   |        34.5        |
# |   13  | lOG-Reg on n-gram 3000 features Count Vectorizer |     0.0001     |    0.44    |   0.97  |    0.98   |        31.3        |
# +-------+--------------------------------------------------+----------------+------------+---------+-----------+--------------------+

# %% [markdown]
# By observing the above table we can say that model that best suits which will best for
# this assignment in order to have the best prediction and low log loss is "Logistic Regression on n-gram 3000 features Count Vectorizer "
# as we find the test and cv log-loss to minimum of all and the misclassified percentage is also less of all
